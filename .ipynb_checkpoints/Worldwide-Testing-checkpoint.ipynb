# %% [markdown]
# # One Genre To Rule Them All... Globally
#
# We're going to analyze the worldwide box office returns of movies based on their genre.
#
# This is the second step in our analysis. The first step was only considering the domestic market and can be found in the `Domestic.ipynb` notebook.
#
# To recap our findings there:
#   - `Horror` is the safest genre to invest in. It's production budget is much lower than spectacle genres, and it has a higher chance of profitability on a per movie basis.
#   - `Action` and `Adventure` are the riskiest genres. They're more expensive, and more often than not, they do not breakeven.
#
# It's time now to see what the addition of the worldwide market does to our study!
#
# # The Worldwide Market
#
# It's difficult to pin down exact totals for the domestic versus worldwide box office, but it's clear with each passing year, more and more of a movie's gross comes from abroad.
#
# [Statista](https://www.statista.com/) has 2018 totals being \\$11.9 billion for the [domestic market](https://www.statista.com/statistics/243180/leading-box-office-markets-workdwide-by-revenue/) and \\$29.2 billion for the [international market](https://www.statista.com/statistics/271856/global-box-office-revenue/).
#
# That puts the total box office ratio at 29% domestic and 71% international.
#
# We will use the same approach as our domestic analysis:
# - Decide which genres to consider in our analysis.
#
# - Decide on a profitability measure.
#
# - Whittle our dataset down to movies released by the Big Five. This is to control for factors like lack of budget or marketing affecting a movie's success. Sure, independent movies can succeed, but our bosses want to see how the genres performed with all the help of a studio behind them.
#
# - Analyze the historical performance of the genres by decade. There might be some trends over time that would be useful to know.
#
# - Analyze the historical performance of the genres by release week. Maybe certain genres perform better at certain times of year.
#
# - Incorporate our findings into a strategy for our bosses!
#
# # Deciding on Genres
#
# According to [The Numbers](https://www.the-numbers.com/market/), the top six genres in terms of box office gross are:
# - Adventure
# - Action
# - Drama
# - Comedy
# - Thriller/Suspense
# - Horror
#
# Our bosses like making money.
#
# Sold.
#
# # Is This Movie Profitable?
#
# The box office share a studio makes from international sales varies incredibly from country to country.
#
# An article on [Gizmodo](https://io9.gizmodo.com/how-much-money-does-a-movie-need-to-make-to-be-profitab-5747305) claims that a good rule of thumb is that a movie breaks even when it earns twice its production budget worldwide.
#
# ## Profitability equation
#
# We will include marketing costs when calculating the breakeven point. These numbers vary greatly from movie to movie, so we will again assume a 50% spend, pegged to each movie's production budget.
#
# **Worldwide box office = 2 * 1.5 * Production budget**
#
# So if a movie earns at least three times its original production budget worldwide, it is a winner!

# %% [markdown]
# # Curate our dataset

# %% [markdown]
# ## Import libraries and settings

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))

pd.options.display.max_rows = 400
pd.options.display.max_columns = 50
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# ## Import data

# %%
data = pd.read_csv('cleaned_movie_data.csv', parse_dates=['release_date'], usecols=['title', 'distributor_mojo', 'worldwide_adj', 'budget_adj',  'genres_mojo', 'release_year', 'release_week', 'release_date'])

# Only look at movies that made money domestically
data = data[data['worldwide_adj'].notna() & data['worldwide_adj'] > 0]

# For decade analysis
data['release_decade'] = data['release_year'].apply(lambda x: x // 10 * 10)

# For breakeven analysis
data['worldwide_breakeven'] = data['worldwide_adj'] >= 3 * data['budget_adj']

# Create columns for genres
# A movie can have multiple genres. If so, we will count them for all the genres its classified with.
data['action'] = data['genres_mojo'].str.contains('Action', na=False)
data['adventure'] = data['genres_mojo'].str.contains('Adventure', na=False) 
data['comedy'] = data['genres_mojo'].str.contains('Comedy', na=False)
data['drama'] = data['genres_mojo'].str.contains('Drama', na=False)
data['horror'] = data['genres_mojo'].str.contains('Horror', na=False)
data['thriller_suspense'] = data['genres_mojo'].str.contains('Thriller|Suspense', na=False, regex=True)

# Remove rows that don't contain one of our genres
data = data[data['action'] | data['adventure'] | data['comedy'] | data['drama'] | data['horror'] | data['thriller_suspense']]

# Create dataframes for the genres
action = data[data['genres_mojo'].str.contains('Action', na=False)]
adventure = data[data['genres_mojo'].str.contains('Adventure', na=False)] 
comedy = data[data['genres_mojo'].str.contains('Comedy', na=False)]
drama = data[data['genres_mojo'].str.contains('Drama', na=False)]
horror = data[data['genres_mojo'].str.contains('Horror', na=False)]
thriller_suspense = data[data['genres_mojo'].str.contains('Thriller|Suspense', na=False, regex=True)]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5631 entries, 3 to 19775
# Data columns (total 16 columns):
# title                  5631 non-null object
# release_year           5631 non-null int64
# distributor_mojo       5631 non-null object
# genres_mojo            5631 non-null object
# release_date           5631 non-null datetime64[ns]
# worldwide_adj          5631 non-null float64
# budget_adj             3749 non-null float64
# release_week           5631 non-null int64
# release_decade         5631 non-null int64
# worldwide_breakeven    5631 non-null bool
# action                 5631 non-null bool
# adventure              5631 non-null bool
# comedy                 5631 non-null bool
# drama                  5631 non-null bool
# horror                 5631 non-null bool
# thriller_suspense      5631 non-null bool
# dtypes: bool(7), datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 478.4+ KB

# %% [markdown]
# ## Organize By Distributors
#
# The [Big Five](https://en.wikipedia.org/wiki/Major_film_studio#Past) studios we will use in our analysis are:
# - Universal
# - Paramount
# - Warner Bros.
# - Disney
# - Sony
#
# Studios have come and gone a lot historically. They get bought out by competitors, or go out of business. A lot of messy stuff.
#
# To simplify, we will categorize a movie by its current studio owner. So for example, Disney [recently purchased](https://theweek.com/speedreads/780191/disney-buys-21st-century-fox-713-billion) 20th Century Fox. So we will categorize a 20th Century Fox movie as Disney.

# %%
data[data['budget_adj'].notna() & data['distributor_mojo'].notna()]['distributor_mojo'].value_counts()
# Out:
# Universal                           355
# Warner Bros.                        346
# Fox                                 301
# Sony / Columbia                     266
# Paramount                           264
# Buena Vista                         217
# New Line                            122
# Miramax                             114
# Fox Searchlight                     106
# Lionsgate                           104
# MGM                                  89
# Sony Classics                        81
# Sony / Screen Gems                   69
# Focus Features                       64
# Warner Bros. (New Line)              49
# Weinstein Company                    49
# IFC                                  46
# DreamWorks                           42
# Lions Gate                           41
# Magnolia                             41
# Columbia                             41
# United Artists                       41
# Roadside Attractions                 35
# TriStar                              34
# Sony (Revolution)                    30
# Open Road Films                      29
# Lionsgate/Summit                     27
# Relativity                           27
# A24                                  25
# Artisan                              21
# Summit Entertainment                 19
# STX Entertainment                    19
# Freestyle Releasing                  19
# Paramount (DreamWorks)               18
# Dimension Films                      17
# Anchor Bay Films                     17
# MGM (Weinstein)                      16
# Weinstein / Dimension                16
# Samuel Goldwyn                       16
# ThinkFilm                            14
# Paramount Vantage                    14
# Orion Pictures                       14
# Fine Line                            14
# Gramercy                             13
# Overture Films                       12
# FilmDistrict                         12
# Newmarket                            11
# CBS Films                            11
# IDP                                  10
# Paramount Classics                   10
# Warner Independent                   10
# BH Tilt                              10
# Rogue Pictures                        9
# Indican                               9
# First Look                            9
# USA Films                             8
# Broad Green Pictures                  8
# Radius-TWC                            8
# Bleecker Street                       7
# Strand                                6
# Monterey Media, Inc.                  6
# Picturehouse                          6
# October                               6
# Yari Film Group                       6
# Annapurna Pictures                    5
# Destination                           5
# Oscilloscope Pictures                 5
# Yash Raj                              5
# Apparition                            5
# Trimark                               5
# Pure Flix                             4
# The Bigger Picture                    4
# Tribeca Film                          4
# Embassy                               4
# PolyGram                              4
# Cannon Films                          4
# Third Rail Releasing                  4
# EuropaCorp                            4
# Excel                                 4
# Unknown                               4
# Fox Atomic                            3
# Screen Media                          3
# Palm                                  3
# Alliance                              3
# Eros                                  3
# First Independent Pictures            3
# Rocky Mountain Pictures               3
# Millennium Ent.                       3
# Drafthouse                            3
# Slowhand Cinema                       3
# Vitagraph                             3
# Focus World                           3
# New World                             3
# Variance Films                        3
# Well Go USA                           3
# Five & Two Pictures                   3
# Kino                                  2
# Phase 4                               2
# Cohen Media Group                     2
# Paramount Insurge                     2
# Lionsgate Premiere                    2
# Studio 8                              2
# Rainforest                            2
# International Film Circuit            2
# Hannover House                        2
# The Orchard                           2
# Alchemy                               2
# Orion Classics                        2
# Vertical Entertainment                2
# LD Entertainment                      2
# Paladin                               2
# Goodbye Cruel Releasing               2
# Wellspring                            2
# Image Entertainment                   2
# Vivendi Entertainment                 2
# Entertainment Studios                 2
# Interstar                             2
# Pantelion                             2
# Savoy                                 2
# Filmways                              2
# Roxie                                 2
# Regent Releasing                      2
# Sony / AFFIRM Films                   2
# Saban Films                           1
# B.D. Fox                              1
# Outsider Films                        1
# 8X Entertainment                      1
# Ten Furlongs                          1
# Good Machine                          1
# Libero, LLC                           1
# CJ Entertainment                      1
# UTV Communications                    1
# Area23a                               1
# Chicago Pictures                      1
# Darius Films                          1
# Matson Films                          1
# Independent                           1
# AVCO Embassy                          1
# ATO Pictures                          1
# Crimson Forest                        1
# Romar Entertainment                   1
# Invincible Pictures                   1
# Electric Entertainment                1
# Mangusta Productions                  1
# Aviron                                1
# Painted Zebra Releasing               1
# AfterLight                            1
# Wingate Distribution                  1
# Cloud Ten                             1
# RBC Radio                             1
# Imperial Ent.                         1
# North/South Pictures                  1
# Gunpowder & Sky                       1
# Quaker Media                          1
# IM Global/Blumhouse                   1
# Disney                                1
# FilmBuff                              1
# Hummingbird Pictures                  1
# TLA Releasing                         1
# ImaginAsian Pictures                  1
# Swipe Films                           1
# SModcast Pictures                     1
# Cowboy                                1
# Brothers' Ink Productions             1
# Cyan Pictures                         1
# Global Road                           1
# RKO                                   1
# Viva Pictures Distribution            1
# Lorimar                               1
# Fader Films                           1
# Big Fat Movies                        1
# American International Pictures       1
# Echo Bridge Entertainment             1
# Neon                                  1
# RLJ Entertainment                     1
# eOne Entertainment                    1
# IndustryWorks                         1
# Wrekin Hill                           1
# Independent Artists                   1
# Priority Films                        1
# EchoLight Studios                     1
# RS                                    1
# Providence                            1
# Scarlet Sky Productions               1
# Fox Meadows Films                     1
# Honorara Productions                  1
# Associated Film Dist.                 1
# Illuminare Entertainment              1
# GVN Releasing                         1
# Millennium Films, Inc.                1
# Lot 47                                1
# New Films Cinema                      1
# Fabrication Films                     1
# Abramorama                            1
# Clarius Entertainment                 1
# Amazon Studios                        1
# Starz Media                           1
# Music Box Films                       1
# Film Foundry                          1
# IndieVest Pictures                    1
# Senator Distribution                  1
# Truly Indie                           1
# Cleopatra Films                       1
# Picturehouse (II)                     1
# Cineville                             1
# Exclusive Media                       1
# Zion                                  1
# PMK*BNC                               1
# Entertainment One                     1
# Circle                                1
# The Film Arcade                       1
# Producers Distribution Agency         1
# Lavendar House Films                  1
# Ocean Avenue Entertainment            1
# United Film Distribution Company      1
# Ketchup Entertainment                 1
# Halestorm                             1
# Atlantic                              1
# Stratosphere                          1
# Cafe Pictures                         1
# First Run                             1
# Compass                               1
# Industrial House                      1
# City Lights Pictures Releasing        1
# Name: distributor_mojo, dtype: int64

# %%
# Create a regex string to combine movies into their respective distributor
# https://en.wikipedia.org/wiki/Major_film_studio#Past
nbcuniversal = 'Universal|Focus Features|Focus World|Gramercy|Working Title|Big Idea|DreamWorks$|Illumination|Carnival|Mac Guff|United International'

print(data[data['distributor_mojo'].str.contains(nbcuniversal, na=False, regex=True)]['distributor_mojo'].value_counts())
print('Sum:', data[data['distributor_mojo'].str.contains(nbcuniversal, na=False, regex=True)]['distributor_mojo'].value_counts().sum())
# Out:
# Universal                       428
# Focus Features                   94
# DreamWorks                       43
# Gramercy                         13
# Focus World                      12
# Universal Home Entertainment      1
# Name: distributor_mojo, dtype: int64
# Sum: 591

# %%
viacom = 'Paramount|BET|Comedy Central|MTV|Nickelodeon|Bardel Entertainment|MTV Animation|Nickelodeon Animation Studio|Awesomeness|CMT|Melange|United International Pictures|VH1|Viacom 18 Motion Pictures'

print(data[data['distributor_mojo'].str.contains(viacom, na=False, regex=True)]['distributor_mojo'].value_counts())
print('Sum:', data[data['distributor_mojo'].str.contains(viacom, na=False, regex=True)]['distributor_mojo'].value_counts().sum())
# Out:
# Paramount                 284
# Paramount Classics         20
# Paramount (DreamWorks)     20
# Paramount Vantage          19
# Paramount Insurge           2
# Name: distributor_mojo, dtype: int64
# Sum: 345

# %%
warnermedia = 'Warner Bros.|CNN Films|HBO|DC Films|New Line|Cartoon Network Studios|Wang Film Productions|Adult Swim Films|Castle Rock Entertainment|Cinemax|Flagship|Fullscreen|Hello Sunshine|Spyglass'

print(data[data['distributor_mojo'].str.contains(warnermedia, na=False, regex=True)]['distributor_mojo'].value_counts())
print('Sum:', data[data['distributor_mojo'].str.contains(warnermedia, na=False, regex=True)]['distributor_mojo'].value_counts().sum())
# Out:
# Warner Bros.               381
# New Line                   139
# Warner Bros. (New Line)     51
# Name: distributor_mojo, dtype: int64
# Sum: 571

# %%
disney = 'Walt Disney|^Fox$|Fox Atomic|A&E|Disneynature|ESPN|Fox Searchlight|Hulu|National Geographic|VICE|Fox Family|Lucasfilm|Marvel|The Muppets Studio|UTV Motion Pictures|20th Century Fox Animation|Blue Sky Studios|Lucasfilm Animation|Marvel Animation|Pixar Animation Studios|Buena Vista|Disney|Dragonfly Film Productions|Fox Star Studios|Fox Studios Australia|Kudos Film|New Regency|Patagonik Film Group|Shine Group|Tiger Aspect Productions|Zero Day Fox'

print(data[data['distributor_mojo'].str.contains(disney, na=False, regex=True)]['distributor_mojo'].value_counts())
print('Sum:', data[data['distributor_mojo'].str.contains(disney, na=False, regex=True)]['distributor_mojo'].value_counts().sum())
# Out:
# Fox                                  361
# Buena Vista                          244
# Fox Searchlight                      138
# Fox Atomic                             4
# National Geographic Entertainment      3
# Disney                                 1
# Name: distributor_mojo, dtype: int64
# Sum: 751

# %%
sony = 'Sony|Columbia|Affirm|Screen Gems|Stage 6|Ghost Corps|Funimation|Madhouse|Manga Entertainment UK|TriStar|Destination Films|Left Bank Pictures|Triumph Films'

print(data[data['distributor_mojo'].str.contains(sony, na=False, regex=True)]['distributor_mojo'].value_counts())
print('Sum:', data[data['distributor_mojo'].str.contains(sony, na=False, regex=True)]['distributor_mojo'].value_counts().sum())
# Out:
# Sony / Columbia        288
# Sony Classics          151
# Sony / Screen Gems      75
# Columbia                44
# TriStar                 38
# Sony (Revolution)       35
# Sony / AFFIRM Films      2
# Sony BMG                 1
# Name: distributor_mojo, dtype: int64
# Sum: 634

# %%
data['universal'] = data['distributor_mojo'].str.contains(nbcuniversal, na=False, regex=True)
data['paramount'] = data['distributor_mojo'].str.contains(viacom, na=False, regex=True)
data['warner'] = data['distributor_mojo'].str.contains(warnermedia, na=False, regex=True)
data['disney'] = data['distributor_mojo'].str.contains(disney, na=False, regex=True)
data['sony'] = data['distributor_mojo'].str.contains(sony, na=False, regex=True)
data['distributor'] = np.nan

# %%
data.loc[data['universal'], 'distributor'] = 'Universal'
data.loc[data['paramount'], 'distributor'] = 'Paramount'
data.loc[data['warner'], 'distributor'] = 'Warner'
data.loc[data['disney'], 'distributor'] = 'Disney'
data.loc[data['sony'], 'distributor'] = 'Sony'

# %%
# We only want to keep rows that have one of the Big Five
data = data[data['distributor'].notna()]

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2892 entries, 20 to 19775
# Data columns (total 22 columns):
# title                  2892 non-null object
# release_year           2892 non-null int64
# distributor_mojo       2892 non-null object
# genres_mojo            2892 non-null object
# release_date           2892 non-null datetime64[ns]
# worldwide_adj          2892 non-null float64
# budget_adj             2453 non-null float64
# release_week           2892 non-null int64
# release_decade         2892 non-null int64
# worldwide_breakeven    2892 non-null bool
# action                 2892 non-null bool
# adventure              2892 non-null bool
# comedy                 2892 non-null bool
# drama                  2892 non-null bool
# horror                 2892 non-null bool
# thriller_suspense      2892 non-null bool
# universal              2892 non-null bool
# paramount              2892 non-null bool
# warner                 2892 non-null bool
# disney                 2892 non-null bool
# sony                   2892 non-null bool
# distributor            2892 non-null object
# dtypes: bool(12), datetime64[ns](1), float64(2), int64(3), object(4)
# memory usage: 282.4+ KB

# %%
data['distributor'].value_counts().plot(kind='pie');

# %% [markdown]
# ## Summary
#
# Our filtered dataset now has 2,892 entries.
#
# The only missing information in our dataframe is in the `budget_adj` column, which is a movie's production budget.
#
# We will just ignore the missing entries when we need the production budget information.
#
# The reason we won't fill in missing budgets with a genre's mean budget is that many movies have multiple genres. This would open the door to bad estimates of a movie's budget. For example, if we have an action comedy movie, do we give it the mean budget of action or comedy? The average of both genres?
#
# We will reassess this decision later if it seems like the lack of budget information is a problem.

# %%
# Example showing how many movies have multiple genres
data[data['budget_adj'].isna()]['genres_mojo'].value_counts()
# Out:
# Drama                 86
# Comedy                68
# Romantic Comedy       32
# Comedy / Drama        25
# Family Comedy         21
# Thriller              21
# Action Comedy         15
# Drama / Thriller      14
# Action                13
# Horror                12
# Crime Drama            9
# Family Adventure       8
# Sci-Fi Adventure       6
# Adventure              6
# Foreign / Action       6
# Action Thriller        6
# Fantasy Comedy         6
# Action Drama           6
# Crime Comedy           5
# Horror Thriller        5
# Romantic Thriller      5
# Sports Drama           5
# Sci-Fi Thriller        4
# Foreign / Horror       4
# Sci-Fi Horror          4
# War Drama              4
# Music Drama            4
# Period Comedy          4
# Sports Comedy          4
# Fantasy Drama          3
# Historical Drama       3
# Period Drama           3
# Action Horror          3
# Action / Crime         3
# Sci-Fi Comedy          2
# Horror Comedy          2
# Adventure Comedy       2
# Comedy Thriller        1
# Period Action          1
# Romantic Adventure     1
# Sports Action          1
# Crime Thriller         1
# Period Adventure       1
# Western Comedy         1
# Action / Adventure     1
# Action Fantasy         1
# Sci-Fi Action          1
# Name: genres_mojo, dtype: int64

# %%
# Create column to compare profitability
data['profit'] = data['worldwide_adj'] - 3 * data['budget_adj']

# %% [markdown]
# # Create Graphing Helper Function and Reusable Lists

# %%
# Tailored from matplotlib documentation
# https://matplotlib.org/examples/api/barchart_demo.html
def autolabel(axis, num_decimals=0, counts=None):
    """
    Attach a text label above each bar displaying its height.
    If sent a list of counts, display those instead.
    """
    for i, val in enumerate(axis.patches):
        if counts is not None:
            height = counts[i]
        else:
            height = round(val.get_height(), num_decimals) if num_decimals > 0 else int(val.get_height())
        
        # We don't want to display zeros on our bar plots
        if height == 0:
            continue
            
        axis.text(val.get_x() + val.get_width()/2, val.get_height()*1.05, '{}'.format(height), ha='center', va='bottom', fontsize=20)

# %%
# Create lists of useful information for graphing
genres = ['action', 'adventure', 'comedy', 'drama', 'horror', 'thriller_suspense']
colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'w']

# Create a summary statistics dataframe separated by genre to make graphing easier
# The columns are:
# Number of movies
# Average gross
# All-time gross
# Average budget
# All-time budget
# Dollar earned for dollar spent (including marketing -- adjusted budget is 1.5 times original budget)

aggregation_stats_per_genre = {
    'num_movies': [data[genre].sum() for genre in genres],
    'avg_gross': [round(data[data[genre]]['worldwide_adj'].mean() / 1000000, 1) for genre in genres],
    'median_gross': [round(data[data[genre]]['worldwide_adj'].median() / 1000000, 1) for genre in genres], 
    'all_time_gross': [round(data[data[genre]]['worldwide_adj'].sum() / 1000000, 1) for genre in genres],
    'avg_budget': [round(data[data[genre]]['budget_adj'].mean() / 1000000, 1) for genre in genres],
    'median_budget': [round(data[data[genre]]['budget_adj'].median() / 1000000, 1) for genre in genres],
    'all_time_budget': [round(data[data[genre]]['budget_adj'].sum() / 1000000, 1) for genre in genres],
    'dollars_earned_for_dollars_spent': [round((data[data[genre]]['worldwide_adj'].sum() / 2000000) / (1.5 * data[data[genre]]['budget_adj'].sum() / 1000000), 1) for genre in genres],
    'median_dollars_earned_for_dollars_spent': [round((data[data[genre]]['worldwide_adj'].median() / 2000000) / (1.5 * data[data[genre]]['budget_adj'].median() / 1000000), 1) for genre in genres],
    'mean_dollars_earned_for_dollars_spent': [round((data[data[genre]]['worldwide_adj'].mean() / 2000000) / (1.5 * data[data[genre]]['budget_adj'].mean() / 1000000), 1) for genre in genres]
}

# %% [markdown]
# # Bird's Eye View Of The Data
#
# We created a custom function for adding numerical labels to our bar plots.
#
# We will do some exploratory data analysis to get a sense of our dataset's breakdown by genre.

# %%
summary = pd.DataFrame(aggregation_stats_per_genre, index=genres)
summary
# Out:
#                    num_movies  avg_gross  median_gross  all_time_gross  \
# action                    537      297.7         187.1        159874.3
# adventure                 276      387.3         249.6        106898.4
# comedy                   1147      125.7          71.2        144159.6
# drama                     826       93.7          48.0         77429.2
# horror                    284      164.9          93.3         46835.8
# thriller_suspense         409      137.1          86.5         56060.0
#
#                    avg_budget  median_budget  all_time_budget  \
# action                  102.3           90.3          49113.0
# adventure               123.8          120.3          31067.6
# comedy                   45.5           35.5          43661.8
# drama                    40.5           30.3          26907.5
# horror                   44.2           31.1          11219.7
# thriller_suspense        56.5           51.0          19876.9
#
#                    dollars_earned_for_dollars_spent  \
# action                                          1.1
# adventure                                       1.1
# comedy                                          1.1
# drama                                           1.0
# horror                                          1.4
# thriller_suspense                               0.9
#
#                    median_dollars_earned_for_dollars_spent  \
# action                                                 0.7
# adventure                                              0.7
# comedy                                                 0.7
# drama                                                  0.5
# horror                                                 1.0
# thriller_suspense                                      0.6
#
#                    mean_dollars_earned_for_dollars_spent
# action                                               1.0
# adventure                                            1.0
# comedy                                               0.9
# drama                                                0.8
# horror                                               1.2
# thriller_suspense                                    0.8

# %% [markdown]
# ## Number of movies

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Number of Movies Per Genre', fontsize=20, y=1.02)

summary.sort_values('num_movies', ascending=False, inplace=True)

summary.plot(y='num_movies', kind='bar', color=colors[0], ax=axis, legend=False)
axis.set_ylabel('')
axis.set_xlabel('')
axis.tick_params(labelsize=20)
autolabel(axis)

plt.tight_layout()

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(18,9))

# Since we are dealing with boolean columns, we must use 'sum' to get the total counts
data.groupby('release_decade').sum().plot.bar(y=['adventure', 'action', 'drama', 'comedy', 'thriller_suspense', 'horror'], ax=ax1, title='Number of Genre Movies Released Worldwide By Decade');

# %% [markdown]
# ### Quick Takeaways
#
# **Number of movies**
#   - `Comedy` and `Drama` are historically the most produced genres by big movie studios by a healthy margin
#   - They have been the top two spots for the last four decades

# %% [markdown]
# ## Worldwide Gross

# %%
# We want individual columns that hold the worldwide gross for each genre
# Since a movie can have multiple genres, right now we must handle this by a groupby while looping over each genre
# If we create individual columns that contain information about a genre and its worldwide box office, it's easier to graph
def worldwide_gross_by_genre(row, genre):
    # Returns either 0 or the `worldwide_adj` value due to boolean multiplication
    test = row[genre] * row['worldwide_adj']
    
    # If the row is not in the genre (i.e. False * $100 = 0)
    if test == 0:
        return np.nan
    else:
        return test

# List of new columns to hold worldwide grosses by genre
worldwide_columns = ['worldwide_gross_{}'.format(genre) for genre in genres]

for genre, col in zip(genres, worldwide_columns):
    data[col] = data.apply(lambda x: worldwide_gross_by_genre(x, genre), axis=1)

# %% [markdown]
# ### Aggregate Across All Genres

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24,9))
figure.suptitle('Worldwide Gross In Aggregate', fontsize=20)

(data['worldwide_adj'] / 1000000).plot.hist(range(0, 2000, 50), ax=axis);
axis.set_xlabel('Millions', fontsize=20);
axis.axvline(data['worldwide_adj'].median() / 1000000, color='k')
axis.axvline(data['worldwide_adj'].mean() / 1000000, color='r')
axis.legend(['Median: {:.1f} million'.format(data['worldwide_adj'].median() / 1000000), 'Mean: {:.1f} million'.format(data['worldwide_adj'].mean() / 1000000)], fontsize=15);

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24,9))
figure.suptitle('Worldwide Profits In Aggregate', fontsize=20)

(data['profit'] / 1000000).plot.hist(ax=axis);
axis.set_xlabel('Millions', fontsize=20);
axis.axvline(data['profit'].median() / 1000000, color='k')
axis.axvline(data['profit'].mean() / 1000000, color='r')
axis.legend(['Median: {:.1f} million'.format(data['profit'].median() / 1000000), 'Mean: {:.1f} million'.format(data['profit'].mean() / 1000000)], fontsize=15);

# %% [markdown]
# ### Quick Takeaways
#
# **Skewed dataset**
#   - Worldwide gross is heavily right-skewed.
#   - It has a much higher median than mean (almost double!)
#   - This fits with our understanding of the movie business -- there are a few megahits that earn outsized returns while the majority of movies earn a little or even lose money

# %% [markdown]
# ### Aggregate By Genre

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('All-Time Gross Per Genre', fontsize=20, y=1.02)

summary.sort_values('all_time_gross', ascending=False, inplace=True)

summary.plot(y='all_time_gross', kind='bar', ax=axis, color=colors[2], legend=False)
axis.set_ylabel('Millions of Dollars', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
autolabel(axis)

plt.tight_layout()

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Total Worldwide Gross By Genre and Decade', fontsize=20, y=1.02)

grp = data.groupby('release_decade')[worldwide_columns].sum() / 1000000000
grp.plot(kind='bar', stacked=True, ax=axis)
axis.set_ylabel('Billions of Dollars', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
axis.legend(genres, fontsize=20)

plt.tight_layout()

# %% [markdown]
# ### Quick Takeaways
#
# **All-Time Gross Per Genre**
#   - In aggregate, `Action`, `Comedy`, then `Adventure` have grossed the most money worldwide
#   - `Action` is ahead of `Comedy` by almost \\$16 billion dollars
#
# **Recent Trends**
#   - Grosses for `Action` and `Adventure` have been increasing since the 1990s
#   - Grosses for `Comedy` have substantially decreased in the 2010s, but it is still the third-highest performing genre
#   - Grosses for the other genres are all in decline

# %% [markdown]
# ### Looking At Mean and Median Grosses

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean and Median Worldwide Gross Per Genre, All-Time', fontsize=20, y=1.02)

summary.sort_values('avg_gross', ascending=False, inplace=True)

summary.plot(y=['avg_gross', 'median_gross'], kind='bar', ax=axis, color=colors[1:3], legend=True)
axis.set_ylabel('Millions of Dollars', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
axis.legend(['Mean', 'Median'], fontsize=20)
autolabel(axis)

plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, sharex=True, sharey=True, figsize=(24,15))
figure.suptitle('Worldwide Gross By Genre', fontsize=20)
ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis in zip(genres, axes_list):
    (data[data[genre]]['worldwide_adj'] / 1000000).plot.hist(range(0, 2000, 50), ax=axis)
    axis.set_title(genre)
    axis.axvline(data[data[genre]]['worldwide_adj'].median() / 1000000, color='k')
    axis.axvline(data[data[genre]]['worldwide_adj'].mean() / 1000000, color='r')
    axis.legend(['Median: {:.1f} million'.format(data[data[genre]]['worldwide_adj'].median() / 1000000), 'Mean: {:.1f} million'.format(data[data[genre]]['worldwide_adj'].mean() / 1000000)], fontsize=15)
    axis.set_xlabel('Millions', fontsize=20)

# %% [markdown]
# ### Quick Takeaways
#
#   - Mean and median gross for `Action` and `Adventure` are far higher than any other genre
#   - The most common gross in every genre except `Adventure` is at most //$50 milllion
#
# **Action / Adventure**
#   - Something to keep in mind is the frequency of movies labeled as `Action / Adventure`. These movies gross more than either `Action` or `Adventure` alone, and thus are boosting the mean gross of both separate genres
#   - Let's investigate this a little further

# %% [markdown]
# ### Action / Adventure

# %%
print('Mean gross of Action/Adventure movies: {:.1f} million'.format(data[data['genres_mojo'] == 'Action / Adventure']['worldwide_adj'].mean() / 1000000))
print('Mean gross of Action (without Adventure component) movies: {:.1f} million'.format(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['worldwide_adj'].mean() / 1000000))
print('Mean gross of Adventure (without Action component) movies: {:.1f} million'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['worldwide_adj'].mean() / 1000000))
# Out:
# Mean gross of Action/Adventure movies: 563.2 million
# Mean gross of Action (without Adventure component) movies: 243.6 million
# Mean gross of Adventure (without Action component) movies: 300.8 million

# %% [markdown]
# #### Action

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Gross By Action Subgenres', fontsize=20)

action_movies = data[data['genres_mojo'].str.contains('Action')]

grp = action_movies.groupby('genres_mojo')['worldwide_adj'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar', ax=axis)
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['worldwide_adj'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False))]['worldwide_adj'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions');
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False))]['worldwide_adj'].mean() / 1000000), xy=(6, 310), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['worldwide_adj'].mean() / 1000000), xy=(6, 250), fontsize=20, color='k')
autolabel(axis);

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Production Budgets By Action Subgenres', fontsize=20)

action_movies = data[data['genres_mojo'].str.contains('Action')]

grp = action_movies.groupby('genres_mojo')['budget_adj'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar', ax=axis)
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['budget_adj'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False))]['budget_adj'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions');
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False))]['budget_adj'].mean() / 1000000), xy=(7, 105), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['budget_adj'].mean() / 1000000), xy=(7, 93), fontsize=20, color='k')
autolabel(axis);

# %% [markdown]
# #### Quick Takeaways
#
#   - `Action / Adventure` and `Sci-Fi Action` are the highest grossing subgenres. They also carry the highest production budgets.
#   - The best discount `Action` subgenres appear to be `Action Horror`, `Action Comedy`, and `Period Action`. They have much lower production budgets, but still bolster average grosses higher than any other main genre (i.e. `Horror`, `Comedy`, `Drama`, and `Thriller/Suspense`

# %% [markdown]
# #### Adventure

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Gross By Adventure Subgenres', fontsize=20)

adventure_movies = data[data['genres_mojo'].str.contains('Adventure')]

grp = adventure_movies.groupby('genres_mojo')['worldwide_adj'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['worldwide_adj'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['worldwide_adj'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions', fontsize=20)
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['worldwide_adj'].mean() / 1000000), xy=(3, 400), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['worldwide_adj'].mean() / 1000000), xy=(3, 310), fontsize=20, color='k')
autolabel(axis);

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Production Budget By Adventure Subgenres', fontsize=20)

adventure_movies = data[data['genres_mojo'].str.contains('Adventure')]

grp = adventure_movies.groupby('genres_mojo')['budget_adj'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['budget_adj'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['budget_adj'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions', fontsize=20)
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['budget_adj'].mean() / 1000000), xy=(4, 128), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['budget_adj'].mean() / 1000000), xy=(4, 110), fontsize=20, color='k')
autolabel(axis);

# %% [markdown]
# #### Quick Takeaways
#
#   - Ignoring `Action / Adventure` for now, all the subgenres for `Adventure` seem solid except for `Romantic Adventure`. They gross at least \\$200 million on average with production budgets less than `Action Adventure`'s \\$156 million
#   - If our studio has the funds for it, `Action Adventure` seems like the most reward for risk option
#   - But we could invest in these subgenres and get in at a lower price point

# %%
data[data['genres_mojo'].str.contains('Action')]['genres_mojo'].value_counts().index #.sort_values(ascending=False)
# Out:
# Index(['Action', 'Action Comedy', 'Action / Adventure', 'Sci-Fi Action',
#        'Action Thriller', 'Action Drama', 'Action Horror', 'Action / Crime',
#        'Period Action', 'Foreign / Action', 'Action Fantasy', 'Sports Action'],
#       dtype='object')

# %%
action_subgenres = data[data['genres_mojo'].str.contains('Action')]['genres_mojo'].value_counts().index


#['Action Comedy', 'Sci-Fi', 'Thriller', 'Drama', 'Horror', 'Crime', 'Period', 'Foreign', 'Fantasy', 'Sports']

#action_grosses = {}

for subgenre in data[data['genres_mojo'].str.contains('Action')]['genres_mojo'].value_counts().index:
    #action_grosses[subgenre] = round(data[(data['genres_mojo'].str.contains(subgenre))]['worldwide_adj'].mean() / 1000000, 1)
    print('{} grosses {:.1f}'.format(subgenre, data[(data['genres_mojo'].str.contains(subgenre))]['worldwide_adj'].mean() / 1000000))

#sorted_action_grosses = [k,v for sorted(action_grosses, key=v)]
#print(sorted_action_grosses)
# Out:
# Action grosses 297.7
# Action Comedy grosses 171.9
# Action / Adventure grosses 563.2
# Sci-Fi Action grosses 423.1
# Action Thriller grosses 242.6
# Action Drama grosses 241.6
# Action Horror grosses 185.7
# Action / Crime grosses 91.3
# Period Action grosses 170.6
# Foreign / Action grosses 72.9
# Action Fantasy grosses 103.4
# Sports Action grosses 66.8

# %%
(data.groupby('genres_mojo')['worldwide_adj'].mean() / 1000000).sort_values(ascending=False)
# Out:
# genres_mojo
# Action / Adventure    563.177726
# Period Adventure      472.410482
# Sci-Fi Action         423.125863
# Sci-Fi Adventure      349.564734
# Action                282.800669
# Adventure             274.055131
# Sci-Fi Horror         265.130784
# Western Comedy        265.033344
# Action Thriller       242.615121
# Action Drama          241.562780
# Period Horror         223.597154
# Family Adventure      215.406832
# Adventure Comedy      201.345893
# Family Comedy         190.497660
# Action Horror         185.677779
# Action Comedy         171.898537
# Horror Thriller       171.718829
# Period Action         170.647870
# Fantasy Comedy        164.383458
# Sci-Fi Comedy         163.266114
# Fantasy Drama         159.086645
# Sci-Fi Thriller       157.524719
# Period Comedy         156.016942
# Horror Comedy         153.310992
# Horror                137.568601
# Romantic Comedy       129.738663
# Romantic Adventure    126.936063
# Thriller              126.452239
# Romantic Thriller     124.023432
# Music Drama           123.356353
# Crime Drama           121.281509
# Crime Comedy          117.205285
# War Drama             105.161414
# Comedy                103.951270
# Action Fantasy        103.445362
# Sports Comedy          96.877289
# Period Drama           91.816851
# Action / Crime         91.324321
# Comedy / Drama         90.834306
# Drama / Thriller       86.485003
# Sports Drama           82.279896
# Foreign / Action       72.923174
# Comedy Thriller        70.782781
# Drama                  68.012121
# Sports Action          66.750422
# Crime Thriller         63.247631
# Historical Drama       62.915674
# Foreign / Horror       28.418494
# Name: worldwide_adj, dtype: float64

# %%
data['profit'] = data['worldwide_adj'] - 3 * data['budget_adj']

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Profit By Adventure Subgenres', fontsize=20)

adventure_movies = data[data['genres_mojo'].str.contains('Adventure')]

grp = adventure_movies.groupby('genres_mojo')['profit'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['profit'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['profit'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions', fontsize=20)
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['profit'].mean() / 1000000), xy=(3, 400), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['profit'].mean() / 1000000), xy=(3, 310), fontsize=20, color='k')
autolabel(axis);

# %%
data[data['genres_mojo'] == 'Adventure Comedy'][['title', 'profit']].sort_values(by='profit', ascending=False)
# Out:
#                                             title       profit
# 3724                             Crocodile Dundee  691468731.0
# 10829                  O Brother, Where Art Thou?   -6101128.0
# 16960                          The Princess Bride  -31256570.0
# 18333                                       Trash  -32121271.0
# 6351                           Gulliver's Travels -116653827.0
# 2226                                 Black Knight -128744415.0
# 19592                                    Year One -140477085.0
# 16286          The Life Aquatic with Steve Zissou -153126664.0
# 8539                             Land of the Lost -270185386.0
# 3726                          Crocodile Dundee II          NaN
# 7967   Journey to the West:The Demons Strike Back          NaN

# %%
data[data['budget_adj'].isna()][['title', 'worldwide_adj']].sort_values(by='worldwide_adj', ascending=False)
# Out:
#                                                    title  worldwide_adj
# 1548                               Avengers:Infinity War   2.048360e+09
# 4661               E.T.:The Extra-Terrestrial (Re-issue)   1.062786e+09
# 12741                               Saturday Night Fever   9.825211e+08
# 12035                          Rambo:First Blood Part II   7.010469e+08
# 4659                             E.T. (20th Anniversary)   6.538143e+08
# 6948                       Home Alone 2:Lost in New York   6.425240e+08
# 3529                                   Coming to America   6.129140e+08
# 13085                  Sherlock Holmes:A Game of Shadows   6.089025e+08
# 9023                                  Look Who's Talking   6.014414e+08
# 16511                           The Mermaid (Mei ren yu)   5.794232e+08
# 10470                  National Treasure:Book of Secrets   5.539035e+08
# 4184                               Detective Chinatown 2   5.440619e+08
# 33                                 101 Dalmatians (1996)   5.132398e+08
# 3726                                 Crocodile Dundee II   5.085951e+08
# 8773                                     Lethal Weapon 2   4.614172e+08
# 6976                            Honey, I Shrunk the Kids   4.510290e+08
# 5975                                     Ghostbusters II   4.361865e+08
# 11741                                  Presumed Innocent   4.251781e+08
# 13274                                         Sister Act   4.145237e+08
# 10968                               Once Upon a Deadpool   3.689917e+08
# 718                        Ace Ventura:When Nature Calls   3.499442e+08
# 17722                               The War of the Roses   3.243908e+08
# 9597                                            Maverick   3.101244e+08
# 6667                                                Heat   3.088366e+08
# 3878                                     Dangerous Minds   2.957912e+08
# 1289                                     Another 48 HRS.   2.949479e+08
# 17890                                        The X-Files   2.914327e+08
# 9518                                       Marley and Me   2.830800e+08
# 1624                                           Backdraft   2.809164e+08
# 18623                                        Under Siege   2.802145e+08
# 10133                                 Mr. Bean's Holiday   2.782283e+08
# 12003                     Raiders of the Lost Ark (IMAX)   2.714126e+08
# 2185                                      Bird on a Wire   2.664712e+08
# 1429                                              Arthur   2.637084e+08
# 1904                                           Beethoven   2.634817e+08
# 3829                                        Daddy's Home   2.572191e+08
# 11284                                         Parenthood   2.557602e+08
# 7967          Journey to the West:The Demons Strike Back   2.526440e+08
# 1031               Alvin and the Chipmunks:The Road Chip   2.487568e+08
# 17248                           The Secret of My Success   2.453529e+08
# 12824                    Scooby-Doo 2:Monsters Unleashed   2.412260e+08
# 2651                                 Broken Arrow (1996)   2.404964e+08
# 12806                                   Scent of a Woman   2.400018e+08
# 15257                               The Devil's Advocate   2.392864e+08
# 523                                      A Perfect World   2.348259e+08
# 13764                            Star Trek:First Contact   2.337070e+08
# 7023                                Hot Shots! Part Deux   2.324309e+08
# 10643                                        Nine Months   2.282211e+08
# 11206                                       Paddington 2   2.273319e+08
# 16068                              The Jewel of the Nile   2.258404e+08
# 7818                                            Jaws 3-D   2.218290e+08
# 19523                                       Working Girl   2.185313e+08
# 12494                                Romancing the Stone   2.092290e+08
# 1905                                     Beethoven's 2nd   2.054786e+08
# 4146                                   Dennis the Menace   2.037890e+08
# 13360                                             Sliver   2.021020e+08
# 3451                                              Cocoon   1.990959e+08
# 15445               The Fast and the Furious:Tokyo Drift   1.973834e+08
# 522                                     A Perfect Murder   1.972474e+08
# 13852                                    Steel Magnolias   1.959435e+08
# 9792                                             Michael   1.916002e+08
# 13410                                           Sneakers   1.883440e+08
# 12389                                         Rising Sun   1.862863e+08
# 9318                                     Made in America   1.823657e+08
# 6465                            Hannah Montana The Movie   1.820595e+08
# 10498                                               Nell   1.807628e+08
# 12251                           Resident Evil:Extinction   1.797383e+08
# 13758              Star Trek VI:The Undiscovered Country   1.786307e+08
# 5854                      Garfield:A Tail of Two Kitties   1.765002e+08
# 10146                                 Mr. Holland's Opus   1.750993e+08
# 18625                       Under Siege 2:Dark Territory   1.718931e+08
# 5295                                     Field of Dreams   1.709788e+08
# 7080                                         Housesitter   1.698518e+08
# 5675                                         French Kiss   1.680355e+08
# 12791                                    Scarface (1983)   1.661055e+08
# 11764                                        Primal Fear   1.642297e+08
# 11449                                      Pete's Dragon   1.640400e+08
# 2698                                               Bruno   1.624667e+08
# 19294                               White Men Can't Jump   1.624299e+08
# 18607                                         Uncle Buck   1.605030e+08
# 8065                                                 K-9   1.584559e+08
# 18571                                      U.S. Marshals   1.577004e+08
# 919                        Aliens Vs. Predator - Requiem   1.560890e+08
# 10996                                       One Fine Day   1.560889e+08
# 11759                                Pride and Prejudice   1.557660e+08
# 15827                                 The Heartbreak Kid   1.547352e+08
# 1033                                              Always   1.501271e+08
# 2643                                      Broadcast News   1.488324e+08
# 4525                                             Dragnet   1.473784e+08
# 14699                                 The Bad News Bears   1.421527e+08
# 16812                                    The Parent Trap   1.418963e+08
# 10229                       Murder on the Orient Express   1.407560e+08
# 5441                                              Fletch   1.391191e+08
# 15514                                            The Fly   1.389088e+08
# 11798                                      Problem Child   1.388502e+08
# 18668                               Underworld:Evolution   1.386828e+08
# 17070                                        The Recruit   1.380978e+08
# 17196               The Santa Clause 3:The Escape Clause   1.379695e+08
# 18951                                  Waiting to Exhale   1.342074e+08
# 19478                                         Wolf Totem   1.332774e+08
# 9896              Miss Congeniality 2:Armed and Fabulous   1.303668e+08
# 6205                                Gorillas in the Mist   1.297977e+08
# 6522                                         Hard Target   1.289242e+08
# 3564                         Confessions of a Shopaholic   1.267997e+08
# 13934                        Stop! Or My Mom Will Shoot!   1.263790e+08
# 16560                                      The Money Pit   1.260109e+08
# 15682                                  The Good Shepherd   1.239099e+08
# 15804                                       The Hard Way   1.209360e+08
# 14921                                 The Breakfast Club   1.202447e+08
# 5978                          Ghosts of Girlfriends Past   1.196483e+08
# 5641                                          Fred Claus   1.184897e+08
# 7820                                 Jaws IV:The Revenge   1.146803e+08
# 917                             Alien:The Director's Cut   1.145594e+08
# 7479                           In the Name of the Father   1.143395e+08
# 16319                                 The Little Rascals   1.140458e+08
# 10494                        Neighbors 2:Sorority Rising   1.130023e+08
# 9514                                    Marked for Death   1.113727e+08
# 5601                                            Fracture   1.106369e+08
# 6577                            Harry and the Hendersons   1.105194e+08
# 4537                          Dragon:The Bruce Lee Story   1.103719e+08
# 2178                                        Biloxi Blues   1.097076e+08
# 9837                       Mighty Morphin' Power Rangers   1.094609e+08
# 2596                                 Brewster's Millions   1.069612e+08
# 7423                                        In Her Shoes   1.068123e+08
# 14037                                       Sudden Death   1.060287e+08
# 15683                                       The Good Son   1.053311e+08
# 1981                                Bend It Like Beckham   1.045142e+08
# 14509                                         The 'Burbs   9.943431e+07
# 12514                                 Rookie of the Year   9.818502e+07
# 12808                 Schindler's List (2018 re-release)   9.689882e+07
# 8257                                          King Ralph   9.676846e+07
# 3923                                             Darkman   9.390768e+07
# 15730                                 The Great Outdoors   9.223933e+07
# 17030                                          The Quest   9.186539e+07
# 19572                             XXX:State of the Union   9.131744e+07
# 19116                                      Weird Science   9.086071e+07
# 18136                       Tinker, Tailor, Soldier, Spy   9.001067e+07
# 4809                            Elizabeth:The Golden Age   8.990736e+07
# 14022                                       Stuck on You   8.977690e+07
# 11423                                   Perfect Stranger   8.851831e+07
# 11200                                    Pacific Heights   8.631530e+07
# 10153                     Mr. Magorium's Wonder Emporium   8.413912e+07
# 3851                                    Dan in Real Life   8.281081e+07
# 16806                                          The Paper   8.204920e+07
# 10081                         Mortal Kombat:Annihilation   8.038062e+07
# 5442                                        Fletch Lives   7.989042e+07
# 18655                                           Underdog   7.904753e+07
# 15515                                         The Fly II   7.878113e+07
# 18170   To Wong Foo, Thanks for Everything, Julie Newmar   7.871676e+07
# 13097                                    Shining Through   7.846107e+07
# 9878                       Miracle on 34th Street (1994)   7.838941e+07
# 15904                                      The Hot Chick   7.626667e+07
# 6236                                        Grand Canyon   7.557423e+07
# 12863                                          Searching   7.546204e+07
# 15398                                   The Exorcist III   7.497523e+07
# 19228                              When a Stranger Calls   7.405636e+07
# 16696                         The Object of My Affection   7.226010e+07
# 1385                                    Are We Done Yet?   7.071241e+07
# 3622                                      Cop and a Half   7.070911e+07
# 11506                                    Picture Perfect   6.935875e+07
# 10468                                  National Security   6.836927e+07
# 909                                         Alien Nation   6.825323e+07
# 15181                                    The Danish Girl   6.800753e+07
# 15339                                           The Edge   6.776337e+07
# 8034                                        Just Friends   6.546067e+07
# 12016                                    Raising Arizona   6.450152e+07
# 838                                          Air America   6.428737e+07
# 10800                                       Now and Then   6.193919e+07
# 5073                   Extremely Loud & Incredibly Close   6.167508e+07
# 11799                                    Problem Child 2   6.029647e+07
# 3490                                   College Road Trip   6.012217e+07
# 4476                                      Down Periscope   6.010204e+07
# 2264                             Blade Runner (re-issue)   5.882838e+07
# 17191                                        The Sandlot   5.879260e+07
# 1754                             Barbershop:The Next Cut   5.757512e+07
# 610                    A Thin Line Between Love and Hate   5.697489e+07
# 12101                                      Reality Bites   5.651018e+07
# 3822                                                 Dad   5.569520e+07
# 19360                                        Wild (2014)   5.568863e+07
# 9349                              Magic in the Moonlight   5.412709e+07
# 4490                                      Down with Love   5.386260e+07
# 3452                                   Cocoon:The Return   5.311862e+07
# 16192                  The Last House on the Left (2009)   5.300572e+07
# 3371                                        Class Action   5.213497e+07
# 17121                                         The Ringer   5.199887e+07
# 15597                                 The Getaway (1994)   5.092961e+07
# 9378                                         Major Payne   4.961514e+07
# 2558                                              Breach   4.959834e+07
# 15952                                         The Hunter   4.959409e+07
# 19231                                       When in Rome   4.956689e+07
# 11473                                     Phantom Thread   4.892303e+07
# 5949                                           Ghost Dad   4.884124e+07
# 17656                                      The Uninvited   4.871928e+07
# 2985                                            Casanova   4.846204e+07
# 11152                                         Out to Sea   4.805750e+07
# 11810                                   Project X (1987)   4.772226e+07
# 3957                                           Day Watch   4.706571e+07
# 15556                                    The Frighteners   4.698728e+07
# 11044                                    Only the Lonely   4.626269e+07
# 11880                                          Pure Luck   4.598460e+07
# ...                                                  ...            ...
# 6892                                           Hitchcock   2.577910e+07
# 17751                                  The Way, Way Back   2.500609e+07
# 13202                                     Silence (2016)   2.483535e+07
# 7999                                             Julieta   2.350716e+07
# 15284                                           The Dish   2.350151e+07
# 18352                                    Trial and Error   2.283990e+07
# 1272                                           Annapolis   2.179374e+07
# 15098                               The Company You Keep   2.116266e+07
# 5371                                       Firehouse Dog   2.095059e+07
# 6929                                       Hollywoodland   2.093026e+07
# 2819                                      Cache (Hidden)   2.082635e+07
# 4076                                    Deception (2008)   2.069160e+07
# 14147                                Surviving Christmas   2.010026e+07
# 9909                      Miss Pettigrew Lives for a Day   1.950622e+07
# 10092                                        Most Wanted   1.852124e+07
# 11769                                           Primeval   1.851890e+07
# 5667                                         Freedomland   1.825462e+07
# 17790                                           The Wife   1.820531e+07
# 2856                                             Calvary   1.791291e+07
# 17025                                        The Pyramid   1.788469e+07
# 8629                                          Le Divorce   1.773033e+07
# 8559                                              Lassie   1.690937e+07
# 15066                                       The Clearing   1.664405e+07
# 15087                                      The Comebacks   1.639695e+07
# 4160                                       Desert Flower   1.633350e+07
# 7108                              How to Eat Fried Worms   1.631238e+07
# 3090                              Chandni Chowk to China   1.573038e+07
# 18447                                       Tully (2018)   1.563646e+07
# 17973                                             Thirst   1.522644e+07
# 18457                        Turbo:A Power Rangers Movie   1.504427e+07
# 13991               Street Fighter:The Legend of Chun-Li   1.493999e+07
# 16852                                  The Perfect Score   1.445866e+07
# 13495                                      Something New   1.430372e+07
# 626                                     A United Kingdom   1.415667e+07
# 14325                                       Tamara Drewe   1.371601e+07
# 10188                                          Mubarakan   1.321505e+07
# 15965                                    The Ice Harvest   1.305932e+07
# 5597                                          Foxcatcher   1.283060e+07
# 13517                                      Son of Rambow   1.267793e+07
# 40                                           102 Not Out   1.221489e+07
# 5252                                            Fearless   1.215619e+07
# 19411                                            Win Win   1.209120e+07
# 16030                               The Interview (2014)   1.199145e+07
# 2518                                          Boy Erased   1.175785e+07
# 7235                                I Know Who Killed Me   1.171082e+07
# 1567                                            B.A.P.S.   1.148096e+07
# 14097                                    Sunshine (1999)   1.146691e+07
# 1960                                               Belle   1.137779e+07
# 16711                              The Old Man & the Gun   1.127712e+07
# 9167                                Love is All You Need   1.079737e+07
# 13610                                            Spartan   1.078432e+07
# 13827                                               Stay   1.072590e+07
# 454                                       A Little Chaos   1.068413e+07
# 7183                                            Hysteria   1.039468e+07
# 12549                                        Ruby Sparks   9.983583e+06
# 17616                            The Truth About Charlie   9.900908e+06
# 7180                                 Hyde Park on Hudson   9.720373e+06
# 17545                                 The Tie That Binds   9.606744e+06
# 12595                              Running with Scissors   9.292948e+06
# 15258                               The Devil's Backbone   9.158132e+06
# 11819                               Promised Land (2012)   8.901394e+06
# 258                                    7 Days in Entebbe   8.685101e+06
# 16061                          The Jane Austen Book Club   8.675626e+06
# 3873                                    Dangerous Ground   8.459008e+06
# 6247                                       Grandma's Boy   8.178761e+06
# 19030                       Warriors of Heaven and Earth   8.117014e+06
# 304                                      A Bigger Splash   7.894739e+06
# 10519                                    Never Die Alone   7.873514e+06
# 5261                                      Feel the Noise   7.812782e+06
# 10462                     National Lampoon's Senior Trip   7.722590e+06
# 6160                                     Good Bye Bafana   7.587232e+06
# 15179                                The Dancer Upstairs   7.133824e+06
# 6291                                           Greenberg   7.086731e+06
# 2969                                            Carriers   6.791503e+06
# 11314                                         Passengers   6.749531e+06
# 17476                                   The Tao of Steve   6.425000e+06
# 15326                                        The Duelist   6.384109e+06
# 14188                                  Sweet and Lowdown   6.325929e+06
# 9590                                              Maudie   6.321723e+06
# 3412                                      Closed Circuit   6.198423e+06
# 2486                                     Born to Be Wild   6.146534e+06
# 3567                                            Confetti   6.107195e+06
# 8608                                       Laurel Canyon   6.021386e+06
# 10272                    My Best Friend's Wedding (2016)   5.971747e+06
# 13245                                         Sin Nombre   5.971402e+06
# 14033                                         Suburbicon   5.916235e+06
# 13355                                      Sleuth (2007)   5.900902e+06
# 4421                                 Don't Come Knocking   5.808719e+06
# 14315                                         Talk to Me   5.786978e+06
# 11291                                     Paris Can Wait   5.754943e+06
# 60                      13 Conversations About One Thing   5.173798e+06
# 1618                              Back to the Future Day   5.138319e+06
# 2566                                  Breakfast on Pluto   5.068754e+06
# 18416                                         True Story   5.000268e+06
# 11377                        Peaceful Warrior (re-issue)   4.796364e+06
# 17047                                The Raid:Redemption   4.489844e+06
# 9512   Mark Felt:The Man Who Brought Down the White H...   4.478918e+06
# 12920                                      Separate Lies   4.438439e+06
# 6549                                  Harrison's Flowers   4.234407e+06
# 1424                             Art School Confidential   4.118639e+06
# 9844                                         Miles Ahead   3.620508e+06
# 4989                              Everybody Wants Some!!   3.557536e+06
# 9494                               Margot at the Wedding   3.509405e+06
# 9344                                       Maggie's Plan   3.506748e+06
# 7889                                        Jimmy's Hall   3.354837e+06
# 16276                                 The Leisure Seeker   3.305248e+06
# 7384                                  Imagine Me and You   3.282458e+06
# 15562                                   The Front Runner   3.242235e+06
# 19211                  When Did You Last See Your Father   3.210196e+06
# 19686                                Youth Without Youth   3.178784e+06
# 12077                                         Raw (2017)   3.172454e+06
# 1461                                        Ask the Dust   3.064174e+06
# 18147                                              Titus   3.025478e+06
# 2925                                      Captive (2015)   2.968050e+06
# 14936                             The Broken Hearts Club   2.944340e+06
# 15677                                       The Good Lie   2.887460e+06
# 17046                                         The Raid 2   2.786693e+06
# 5208                                    Fast Food Nation   2.751866e+06
# 18429                                              Truth   2.692960e+06
# 4764                                         El Jeremias   2.657622e+06
# 9945                                    Mistress America   2.649075e+06
# 1153                                             Amreeka   2.547277e+06
# 11696                                        Poster Boys   2.526920e+06
# 4812                                                Elle   2.449827e+06
# 6010                                           Girlfight   2.429450e+06
# 17113                                          The Rider   2.419031e+06
# 9168                                     Love is Strange   2.399551e+06
# 9730                               Men, Women & Children   2.376546e+06
# 1523                                          Austenland   2.327255e+06
# 16296                              The Limits of Control   2.301793e+06
# 1459                                 Ashes of Time Redux   2.230529e+06
# 4872                                       Enduring Love   2.224764e+06
# 12238                                   Reservation Road   2.159579e+06
# 1481                                              Asylum   2.114240e+06
# 4137                                          Demolition   2.070099e+06
# 13060                                        She Hate Me   2.023714e+06
# 369                                    A Fantastic Woman   2.020988e+06
# 19595                                    Year of the Dog   1.942770e+06
# 7426                                       In My Country   1.917611e+06
# 13520                                        Son of Saul   1.882683e+06
# 7590                                           Interview   1.762592e+06
# 7256                                     I Saw the Light   1.722950e+06
# 1657                                            Bad Moon   1.689291e+06
# 6699                                             Heights   1.679551e+06
# 2898                                           Capernaum   1.661096e+06
# 18205                                       Toni Erdmann   1.547807e+06
# 7531                               Infinitely Polar Bear   1.515703e+06
# 8920                                    Little Manhattan   1.437366e+06
# 9481                                   Maps to the Stars   1.417927e+06
# 5534                            For a Good Time, Call...   1.369038e+06
# 14044                                              Sugar   1.339519e+06
# 16039                                The Invisible Woman   1.330416e+06
# 10526                                    Never Look Away   1.304042e+06
# 10938                                     On a Clear Day   1.267065e+06
# 2238                                           Black Sea   1.241205e+06
# 1168                                An American Rhapsody   1.205562e+06
# 14409                                             Tekken   1.132267e+06
# 14746                              The Beautiful Country   1.129306e+06
# 8213                                  Kill Your Darlings   1.110318e+06
# 238                                         5 Flights Up   1.081612e+06
# 2349                                       Bloody Sunday   1.079283e+06
# 16444                                  The Man Who Cried   1.059289e+06
# 3127                                      Charlotte Gray   1.051210e+06
# 5320                   Film Stars Don't Die in Liverpool   1.051187e+06
# 17277                                The Shape of Things   1.004417e+06
# 16821                           The Passenger (re-issue)   9.663790e+05
# 7954                                              Joshua   8.719360e+05
# 15485                                   The First Grader   7.978680e+05
# 18255                                      Touch of Pink   7.724030e+05
# 7292                            I'll Sleep When I'm Dead   6.526440e+05
# 17297                                  The Signal (2014)   6.373730e+05
# 5600                                             Foxtrot   6.188830e+05
# 602                          A Tale of Love and Darkness   5.986760e+05
# 1942                                         Being Flynn   5.907640e+05
# 5764                                          Full of It   5.894580e+05
# 9187                                     Loveless (2018)   5.663560e+05
# 11124                                  Our Little Sister   5.566000e+05
# 15800                                   The Happy Prince   4.664400e+05
# 5333                                      Final Portrait   4.619720e+05
# 16479                          The Marc Pease Experience   4.571630e+05
# 8537                                        Land of Mine   4.553960e+05
# 19443                                    Winter Solstice   4.340910e+05
# 13384                                            Smashed   4.118840e+05
# 1482                                        At Any Price   4.102470e+05
# 649                     A Woman, A Gun and A Noodle Shop   3.595860e+05
# 19415                                         Wind Chill   3.452290e+05
# 8992                                         Lola Versus   2.762720e+05
# 18430                        Truth or Consequences, N.M.   1.909450e+05
# 8656                                      League of Gods   1.900330e+05
# 65                                            13 Minutes   1.654760e+05
# 1757                                        Barely Legal   1.072820e+05
# 1162            An Alan Smithee Film:Burn Hollywood Burn   8.141700e+04
# 18969                                      Walk of Shame   6.280300e+04
# 10163                                          Mr. Right   3.629900e+04
# 14439                                          Term Life   2.223900e+04
# 9203                                        Loving Pablo   2.201700e+04
# 698                                          Abracadabra   1.431600e+04
# 11092                                                Oro   5.674000e+03
# 12861                                       Search Party   4.782000e+03
# 4772                                            El Pacto   2.488000e+03
#
# [439 rows x 2 columns]

# %%
data[data['title'].str.contains('Avengers', na=False)]
# Out:
#                         title  release_year distributor_mojo  \
# 1547   Avengers:Age of Ultron          2015      Buena Vista
# 1548    Avengers:Infinity War          2018      Buena Vista
# 9540    Marvel's The Avengers          2012      Buena Vista
# 14676     The Avengers (1998)          1998     Warner Bros.
#
#               genres_mojo release_date  worldwide_adj   budget_adj  \
# 1547   Action / Adventure   2015-05-01   1.488951e+09  264861803.0
# 1548   Action / Adventure   2018-04-27   2.048360e+09          NaN
# 9540   Action / Adventure   2012-05-04   1.661126e+09  240614040.0
# 14676       Action Comedy   1998-08-14   3.602529e+07   92432025.0
#
#        release_week  release_decade  worldwide_breakeven  action  adventure  \
# 1547             18            2010                 True    True       True
# 1548             17            2010                False    True       True
# 9540             18            2010                 True    True       True
# 14676            33            1990                False    True      False
#
#        comedy  drama  horror  thriller_suspense  universal  paramount  warner  \
# 1547    False  False   False              False      False      False   False
# 1548    False  False   False              False      False      False   False
# 9540    False  False   False              False      False      False   False
# 14676    True  False   False              False      False      False    True
#
#        disney   sony distributor       profit  worldwide_gross_action  \
# 1547     True  False      Disney  694365617.0            1.488951e+09
# 1548     True  False      Disney          NaN            2.048360e+09
# 9540     True  False      Disney  939283924.0            1.661126e+09
# 14676   False  False      Warner -241270787.0            3.602529e+07
#
#        worldwide_gross_adventure  worldwide_gross_comedy  \
# 1547                1.488951e+09                     NaN
# 1548                2.048360e+09                     NaN
# 9540                1.661126e+09                     NaN
# 14676                        NaN              36025288.0
#
#        worldwide_gross_drama  worldwide_gross_horror  \
# 1547                     NaN                     NaN
# 1548                     NaN                     NaN
# 9540                     NaN                     NaN
# 14676                    NaN                     NaN
#
#        worldwide_gross_thriller_suspense
# 1547                                 NaN
# 1548                                 NaN
# 9540                                 NaN
# 14676                                NaN

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Gross By Action Subgenres', fontsize=20)

action_movies = data[data['genres_mojo'].str.contains('Action')]

grp = action_movies.groupby('genres_mojo')['profit'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar', ax=axis)
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['profit'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False))]['profit'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions');
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False))]['profit'].mean() / 1000000), xy=(6, 310), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['profit'].mean() / 1000000), xy=(6, 250), fontsize=20, color='k')
autolabel(axis);

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Median Gross By Action Subgenres', fontsize=20)

action_movies = data[data['genres_mojo'].str.contains('Action')]

grp = action_movies.groupby('genres_mojo')['profit'].median().sort_values(ascending=False) / 1000000

grp.plot(kind='bar', ax=axis)
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['profit'].median() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Action', na=False))]['profit'].median() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions');
axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False))]['profit'].median() / 1000000), xy=(6, 310), fontsize=20, color='r')
axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Action', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['profit'].median() / 1000000), xy=(6, 250), fontsize=20, color='k')
autolabel(axis);

# %% [markdown]
# ### Looking At `Profit`

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Production Budget By Adventure Subgenres', fontsize=20)

adventure_movies = data[data['genres_mojo'].str.contains('Adventure')]

grp = adventure_movies.groupby('genres_mojo')['budget_adj'].mean().sort_values(ascending=False) / 1000000

grp.plot(kind='bar')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['budget_adj'].mean() / 1000000, color='k')
axis.axhline(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['budget_adj'].mean() / 1000000, color='r')
axis.tick_params(labelsize=20)
axis.set_xlabel('')
axis.set_ylabel('Millions', fontsize=20)
#axis.annotate('Mean With Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False))]['budget_adj'].mean() / 1000000), xy=(4, 128), fontsize=20, color='r')
#axis.annotate('Mean Without Action / Adventure: {:.1f}'.format(data[(data['genres_mojo'].str.contains('Adventure', na=False)) & (~data['genres_mojo'].isin(['Action / Adventure']))]['budget_adj'].mean() / 1000000), xy=(4, 110), fontsize=20, color='k')
autolabel(axis);

# %%
grp = data.groupby('genres_mojo')['profit'].mean().sort_values(ascending=False) / 1000000
grp.plot(kind='bar', figsize=(24,9))

# %%
grp = data[data['genres_mojo'].str.contains('Comedy', na=False)].groupby('genres_mojo')['profit'].mean().sort_values(ascending=False) / 1000000
grp.plot(kind='bar', figsize=(24,9))

# %% [markdown]
# ### Quick Takeaways
#
#   - Mean and median gross for `Action` and `Adventure` are far higher than any other genre
#   - Something to keep in mind is the frequency of movies labeled as `Action / Adventure`. These movies gross more than either `Action` or `Adventure` alone, and thus is boosting the mean gross of both separate genres
#
#
#
#
#
#
#
#
#
#
#   Since both of these genres tend to be high grossers, this artificially raises both We have a lot of duplicated movie entries when looking at total numbers. The reason is many movies are categorized as `Action / Adventure`. These movies tend to make a lot of money. This artificially boosts the totals for both `Action` and `Adventure`.

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean Worldwide Gross By Genre and Decade', fontsize=20, y=1.02)

grp = data.groupby('release_decade')[worldwide_columns].mean() / 1000000
grp.plot(kind='bar', stacked=True, ax=axis)
axis.set_ylabel('Millions of Dollars', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
axis.legend(genres, fontsize=20)

plt.tight_layout()

# %% [markdown]
# ### Quick Takeaways
#
# **All-Time Gross Per Genre**
#   - In aggregate, `Action`, `Comedy`, then `Adventure` have grossed the most money worldwide
#   - `Action` is ahead of `Comedy` by almost \\$16 billion dollars
#
# **Average worldwide gross**
#   - `Adventure` and `Action` historically gross the highest average amount per movie
#   - `Adventure` has an average worldwide gross that is more than double the genre in third place
#   - Perhaps surprisingly, `Horror` is in third place
#
# **Skewed dataset**
#   - Our dataset in aggregate and when separated by genre is heavily right-skewed.
#   - Our worldwide grosses have much higher medians than means
#   - This fits with our understanding of the movie business -- there are a few megahits that earn outsized returns while the majority of movies earn a little or even lose money
#   - As an example of how skewed our dataset is, our worldwide mean gross is nearly double our median!

# %% [markdown]
# ## Production budget

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Mean and Median Production Budget Per Genre, All-Time', fontsize=20, y=1.02)

summary.sort_values('avg_budget', ascending=False, inplace=True)

summary.plot(y=['avg_budget', 'median_budget'], kind='bar', ax=axis, color=colors[3:5], legend=True)
axis.set_ylabel('Millions of Dollars', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
axis.legend(['Mean', 'Median'], fontsize=20)
autolabel(axis)

plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, sharex=True, sharey=True, figsize=(24,15))
figure.suptitle('Production Budgets By Genre', fontsize=20)
ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis in zip(genres, axes_list):
    (data[data[genre]]['budget_adj'] / 1000000).plot.hist(ax=axis)
    axis.set_title(genre)
    axis.axvline(data[data[genre]]['budget_adj'].median() / 1000000, color='k')
    axis.axvline(data[data[genre]]['budget_adj'].mean() / 1000000, color='r')
    axis.legend(['Median: {:.1f} million'.format(data[data[genre]]['budget_adj'].median() / 1000000), 'Mean: {:.1f} million'.format(data[data[genre]]['budget_adj'].mean() / 1000000)], fontsize=15)
    axis.set_xlabel('Millions', fontsize=20)

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24,9))
figure.suptitle('Production Budgets In Aggregate', fontsize=20)

(data['budget_adj'] / 1000000).plot.hist(ax=axis);
axis.set_xlabel('Millions', fontsize=20);
axis.axvline(data['budget_adj'].median() / 1000000, color='k')
axis.axvline(data['budget_adj'].mean() / 1000000, color='r')
axis.legend(['Median: {:.1f} million'.format(data['budget_adj'].median() / 1000000), 'Mean: {:.1f} million'.format(data['budget_adj'].mean() / 1000000)], fontsize=15);

# %% [markdown]
# ### Quick Takeaways
#
# **Average production budget**
#   - `Adventure` and `Action` have by far the largest average production budget. This makes sense, as those movies tend to require more setpieces and CGI than other genres
#   - Both `Adventure` and `Action` are at least double the average production budget of the third place genre, `Thriller/Suspense`
#   - `Comedy`, `Horror`, and `Drama` all have very similar, low average production budgets
#   - Production budgets are also right-skewed, but they have far less skew than worldwide grosses
#
# **Low budgets?**
#   - We can tell by the median production budget of 41.2 million that the majority of movies produced have a relatively small budget
#   - Blockbusters (those costing 200-300 million dollars) are the exception, rather than the rule
#   - Something to keep in mind is if this trend has changed in the past decade

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,9))
figure.suptitle('Number of Movies Made In Each Genre By Budget', fontsize=20, y=1.05)
ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

budgets = range(50000000, 350000000, 50000000)

for budget, axis in zip(budgets, axes_list):
    data[(data['budget_adj'] >= 0 + budget) & (data['budget_adj'] < 50000000 + budget)][genres].sum().plot(kind='pie', ax=axis, fontsize=15)
    axis.set_ylabel('')
    axis.set_title('Budget: {:,} - {:,}'.format(0 + budget, 50000000 + budget), fontsize=20)
    
plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,9))
figure.suptitle('Number of Movies In Each Gross Range By Genre', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

grosses = range(0, 1200000000, 200000000)

for gross, axis in zip(grosses, axes_list):
    data[(data['worldwide_adj'] >= 0 + gross) & (data['worldwide_adj'] < gross + 200000000)][worldwide_columns].count().plot(kind='pie', ax=axis, fontsize=15, labels=genres)
    axis.set_ylabel('')
    axis.set_title('Gross: {:,} - {:,}'.format(0 + gross, 200000000 + gross), fontsize=20)
    
plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,9))
ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

grosses = range(0, 1200000000, 200000000)

for gross, axis in zip(grosses, axes_list):
    data[(data['worldwide_adj'] >= 0 + gross) & (data['worldwide_adj'] < gross + 200000000) & (data['release_year'] >= 2010)][worldwide_columns].sum().plot(kind='pie', ax=axis, fontsize=15, labels=genres)
    axis.set_ylabel('')
    axis.set_title('Gross: {:,} - {:,}'.format(0 + gross, 200000000 + gross), fontsize=20)
    
plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20,9))
figure.suptitle('Ratio of Total Gross By Decade And Genre', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

decades = range(1960, 2020, 10)

for decade, axis in zip(decades, axes_list):
    data[data['release_decade'] == decade][worldwide_columns].sum().plot(kind='pie', ax=axis, fontsize=15, labels=genres)
    axis.set_ylabel('')
    axis.set_title('{}s'.format(decade), fontsize=20)
    
plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=6, ncols=2, figsize=(20,40))
figure.suptitle('Ratio Versus Total Gross By Decade And Genre', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12 = axes.flatten()
axes_list1 = [ax1, ax3, ax5, ax7, ax9, ax11]
axes_list2 = [ax2, ax4, ax6, ax8, ax10, ax12]

decades = range(1960, 2020, 10)

for decade, axis1, axis2 in zip(decades, axes_list1, axes_list2):
    (data[data['release_decade'] == decade][worldwide_columns].sum() / 1000000000).plot(kind='pie', ax=axis1, fontsize=12, labels=genres)
    (data[data['release_decade'] == decade][worldwide_columns].sum() / 1000000000).plot(kind='bar', ax=axis2, fontsize=12, ylim=(0,80))
    axis1.set_ylabel('')
    axis1.set_title('{}s Ratios'.format(decade), fontsize=20)
    axis2.set_xticklabels(genres)
    axis2.set_title('{}s Totals'.format(decade), fontsize=20)
    axis2.set_ylabel('Billions', fontsize=20)
plt.tight_layout()

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24,9))
figure.suptitle('Total Box Office By Decade', fontsize=20, y=1.02)

(data.groupby('release_decade')['worldwide_adj'].sum() / 1000000000).plot(kind='bar', fontsize=20)
axis.set_ylabel('Billions', fontsize=20)
axis.set_xlabel('');

# %%
grp = data[data['budget_adj'] >= 100000000][genres]
grp.sum()
# Out:
# action               210
# adventure            146
# comedy                83
# drama                 49
# horror                23
# thriller_suspense     42
# dtype: int64

# %%
ax = grp.sum().plot(kind='pie')
ax.set_ylabel('');

# %%
data[['title', 'genres_mojo', 'worldwide_adj']].sort_values(by='worldwide_adj', ascending=False)
# Out:
#                                                    title         genres_mojo  \
# 1543                                              Avatar    Sci-Fi Adventure
# 15395                                       The Exorcist              Horror
# 7815                                                Jaws     Horror Thriller
# 4660                          E.T.:The Extra-Terrestrial    Family Adventure
# 1548                               Avengers:Infinity War  Action / Adventure
# 8021                                       Jurassic Park       Sci-Fi Horror
# 8025                                      Jurassic World  Action / Adventure
# 9540                               Marvel's The Avengers  Action / Adventure
# 5784                                           Furious 7              Action
# 15649                                      The Godfather         Crime Drama
# 1547                              Avengers:Age of Ultron  Action / Adventure
# 2233                                       Black Panther  Action / Adventure
# 11550          Pirates of the Caribbean:Dead Man's Chest    Period Adventure
# 7649                                          Iron Man 3  Action / Adventure
# 8027                       Jurassic World:Fallen Kingdom  Action / Adventure
# 7507                                    Independence Day       Sci-Fi Action
# 15446                            The Fate of the Furious              Action
# 18319                      Transformers:Dark of the Moon       Sci-Fi Action
# 13315                                            Skyfall              Action
# 2909                           Captain America:Civil War  Action / Adventure
# 15193                              The Dark Knight Rises     Action Thriller
# 901                           Alice in Wonderland (2010)    Family Adventure
# 18318                     Transformers:Age of Extinction       Sci-Fi Action
# 15190                                    The Dark Knight  Action / Adventure
# 11552         Pirates of the Caribbean:On Stranger Tides    Period Adventure
# 11549            Pirates of the Caribbean:At World's End    Period Adventure
# 14119                                           Superman  Action / Adventure
# 5572                                        Forrest Gump      Comedy / Drama
# 1366                                             Aquaman  Action / Adventure
# 13641                                         Spider-Man  Action / Adventure
# 12479                        Rogue One:A Star Wars Story    Sci-Fi Adventure
# 13644                                       Spider-Man 3  Action / Adventure
# 4661               E.T.:The Extra-Terrestrial (Re-issue)    Sci-Fi Adventure
# 13643                                       Spider-Man 2  Action / Adventure
# 12002                            Raiders of the Lost Ark    Period Adventure
# 17313                                    The Sixth Sense              Horror
# 16087                             The Jungle Book (2016)           Adventure
# 16495                                The Matrix Reloaded       Sci-Fi Action
# 8005                       Jumanji:Welcome to the Jungle              Action
# 12741                               Saturday Night Fever         Music Drama
# 18320                 Transformers:Revenge of the Fallen       Sci-Fi Action
# 16391                       The Lost World:Jurassic Park       Sci-Fi Horror
# 14443                          Terminator 2:Judgment Day       Sci-Fi Action
# 7516                  Indiana Jones and the Last Crusade    Period Adventure
# 7499                                           Inception       Sci-Fi Action
# 15176                                  The Da Vinci Code            Thriller
# 13621                                            Spectre              Action
# 9721                                        Men in Black       Sci-Fi Comedy
# 7515   Indiana Jones and the Kingdom of the Crystal S...    Period Adventure
# 6946                                          Home Alone       Family Comedy
# 1792                   Batman v Superman:Dawn of Justice  Action / Adventure
# 17394                                          The Sting        Crime Comedy
# 13647                              Spider-Man:Homecoming  Action / Adventure
# 1544                              Avatar:Special Edition    Sci-Fi Adventure
# 2413                                   Bohemian Rhapsody               Drama
# 1617                                  Back to the Future    Sci-Fi Adventure
# 134                                                 2012        Action Drama
# 11553  Pirates of the Caribbean:The Curse of the Blac...    Period Adventure
# 6337                      Guardians of the Galaxy Vol. 2  Action / Adventure
# 18022                                      Thor:Ragnarok  Action / Adventure
# 11746                                       Pretty Woman     Romantic Comedy
# 18313                                       Transformers       Sci-Fi Action
# 18818                                       Venom (2018)              Action
# 1401                                          Armageddon       Sci-Fi Action
# 5204                                    Fast & Furious 6              Action
# 19505                                       Wonder Woman  Action / Adventure
# 1783                                              Batman  Action / Adventure
# 14602                             The Amazing Spider-Man  Action / Adventure
# 4017                                            Deadpool              Action
# 6335                             Guardians of the Galaxy  Action / Adventure
# 18220                                            Top Gun        Action Drama
# 11551    Pirates of the Caribbean:Dead Men Tell No Tales    Period Adventure
# 7517                Indiana Jones and the Temple of Doom    Period Adventure
# 9931                               Mission:Impossible II              Action
# 19564                          X-Men:Days of Future Past  Action / Adventure
# 18507                                            Twister        Action Drama
# 1086                                   American Graffiti       Period Comedy
# 9928                        Mission:Impossible - Fallout              Action
# 4018                                          Deadpool 2              Action
# 14052                                      Suicide Squad  Action / Adventure
# 9929                 Mission:Impossible - Ghost Protocol              Action
# 19013                                  War of the Worlds       Sci-Fi Horror
# 10180                                     Mrs. Doubtfire       Family Comedy
# 2055                                   Beverly Hills Cop       Action Comedy
# 7816                                              Jaws 2     Horror Thriller
# 6258                                             Gravity     Sci-Fi Thriller
# 2911                  Captain America:The Winter Soldier  Action / Adventure
# 3954                      Dawn of the Planet of the Apes       Sci-Fi Action
# 14603                           The Amazing Spider-Man 2  Action / Adventure
# 3724                                    Crocodile Dundee    Adventure Comedy
# 2995                                       Casino Royale              Action
# 9927                                  Mission:Impossible              Action
# 15205                             The Day After Tomorrow        Action Drama
# 6450                                             Hancock       Fantasy Drama
# 9930                   Mission:Impossible - Rogue Nation              Action
# 9423                                        Man of Steel  Action / Adventure
# 12426                       Robin Hood:Prince of Thieves    Period Adventure
# 10600                                Night at the Museum    Family Adventure
# 7648                                          Iron Man 2  Action / Adventure
# 7680                                                  It              Horror
# 5970                                        Ghostbusters       Horror Comedy
# 7588                                        Interstellar    Sci-Fi Adventure
# 7193                                         I Am Legend       Sci-Fi Horror
# 4371                                      Doctor Strange  Action / Adventure
# 8250                                           King Kong    Period Adventure
# 5225                                    Fatal Attraction            Thriller
# 5206                                           Fast Five              Action
# 12035                          Rambo:First Blood Part II              Action
# 19313                            Who Framed Roger Rabbit      Fantasy Comedy
# 16494                                         The Matrix       Sci-Fi Action
# 18023                                Thor:The Dark World  Action / Adventure
# 11906                                  Quantum of Solace              Action
# 9680                                    Meet the Fockers              Comedy
# 9265                                               MIB 3       Sci-Fi Comedy
# 7647                                            Iron Man  Action / Adventure
# 8057                                      Justice League  Action / Adventure
# 8830                                          Life of Pi           Adventure
# 1619                          Back to the Future Part II    Sci-Fi Adventure
# 2697                                      Bruce Almighty      Fantasy Comedy
# 15790                               The Hangover Part II              Comedy
# 4659                             E.T. (20th Anniversary)    Sci-Fi Adventure
# 6948                       Home Alone 2:Lost in New York       Family Comedy
# 10857                                     Ocean's Eleven        Crime Comedy
# 2056                                Beverly Hills Cop II       Action Comedy
# 8984                                        Logan (2017)  Action / Adventure
# 1774                                      Basic Instinct            Thriller
# 18412                                          True Lies       Action Comedy
# 17328                                         The Smurfs       Family Comedy
# 15565                                       The Fugitive     Action Thriller
# 16587                                          The Mummy    Period Adventure
# 3000                                           Cast Away               Drama
# 1306                                Ant-Man and the Wasp              Action
# 18321                       Transformers:The Last Knight       Sci-Fi Action
# 9724                                     Men in Black II       Sci-Fi Comedy
# 16590                                  The Mummy Returns    Period Adventure
# 10129                                   Mr. & Mrs. Smith       Action Comedy
# 3529                                   Coming to America     Romantic Comedy
# 3122                   Charlie and the Chocolate Factory    Family Adventure
# 13085                  Sherlock Holmes:A Game of Shadows           Adventure
# 2282                                     Blazing Saddles      Western Comedy
# 14386                                                Ted              Comedy
# 4264                           Die Hard:With A Vengeance     Action Thriller
# 9023                                  Look Who's Talking       Family Comedy
# 13083                                    Sherlock Holmes           Adventure
# 16486                                           The Mask              Comedy
# 15506                                    The Flintstones       Family Comedy
# 14446                  Terminator 3:Rise of the Machines       Sci-Fi Action
# 16497                             The Matrix Revolutions       Sci-Fi Action
# 6098                                            Godzilla       Sci-Fi Action
# 12092                                   Ready Player One       Sci-Fi Action
# 1119                                     American Sniper               Drama
# 8342                                   Kong:Skull Island  Action / Adventure
# 16511                           The Mermaid (Mei ren yu)       Fantasy Drama
# 19529                                        World War Z       Action Horror
# 8774                                     Lethal Weapon 3       Action Comedy
# 19566                               X-Men:The Last Stand  Action / Adventure
# 1241                                     Angels & Demons            Thriller
# 13197                                              Signs       Sci-Fi Horror
# 17936                       There's Something About Mary     Romantic Comedy
# 1347                                           Apollo 13     Action Thriller
# 19563                                   X-Men:Apocalypse  Action / Adventure
# 17108                                       The Revenant  Action / Adventure
# 6100                                     Godzilla (2014)       Sci-Fi Action
# 12807                                   Schindler's List           War Drama
# 19567                                    X2:X-Men United  Action / Adventure
# 1788                                      Batman Forever  Action / Adventure
# 10470                  National Treasure:Book of Secrets           Adventure
# 196                                                  300       Period Action
# 1305                                             Ant-Man  Action / Adventure
# 10789                                       Notting Hill     Romantic Comedy
# 15788                                       The Hangover              Comedy
# 19183                                    What Women Want      Fantasy Comedy
# 10457                    National Lampoon's Animal House              Comedy
# 4184                               Detective Chinatown 2       Action Comedy
# 12950                                              Seven            Thriller
# 4091                                         Deep Impact        Action Drama
# 17145                                           The Rock              Action
# 14884                               The Bourne Ultimatum     Action Thriller
# 1067                                     American Beauty               Drama
# 13623                                              Speed     Action Thriller
# 903                                                Alien       Sci-Fi Horror
# 12383                     Rise of the Planet of the Apes       Sci-Fi Action
# 11185                          Oz The Great and Powerful           Adventure
# 16505                                            The Meg     Sci-Fi Thriller
# 14399                Teenage Mutant Ninja Turtles (2014)  Action / Adventure
# 8024                                   Jurassic Park III       Sci-Fi Horror
# 1032              Alvin and the Chipmunks:The Squeakquel       Family Comedy
# 11575                          Planet of the Apes (2001)       Sci-Fi Action
# 33                                 101 Dalmatians (1996)       Family Comedy
# 8023                                    Jurassic Park 3D       Sci-Fi Horror
# 3726                                 Crocodile Dundee II    Adventure Comedy
# 5428                                          Flashdance         Music Drama
# 13754                            Star Trek Into Darkness    Sci-Fi Adventure
# 7097                      How the Grinch Stole Christmas       Family Comedy
# 18245                                       Total Recall       Sci-Fi Action
# 19009                     War for the Planet of the Apes       Sci-Fi Action
# 18019                                               Thor  Action / Adventure
# 9872                                     Minority Report     Sci-Fi Thriller
# 9932                              Mission:Impossible III              Action
# 12059                                             Ransom            Thriller
# ...                                                  ...                 ...
# 14462                                 Testament of Youth               Drama
# 9512   Mark Felt:The Man Who Brought Down the White H...               Drama
# 8012                                             Junebug      Comedy / Drama
# 2598                                          Brick Lane               Drama
# 17779                                 The White Countess        Period Drama
# 12920                                      Separate Lies    Drama / Thriller
# 3671                                    Cradle Will Rock        Period Drama
# 7677                                     Isn't She Great      Comedy / Drama
# 14115                                         Supercross       Sports Action
# 6549                                  Harrison's Flowers           War Drama
# 13151                           Showdown in Little Tokyo              Action
# 1424                             Art School Confidential              Comedy
# 12559                                  Rules Don't Apply      Comedy / Drama
# 7835                                  Jefferson in Paris    Historical Drama
# 16581                                         The Mother               Drama
# 8874                                               Limbo               Drama
# 17701                                       The Wackness              Comedy
# 1532                                          Auto Focus               Drama
# 3045                           Celeste and Jesse Forever      Comedy / Drama
# 2796                                          By the Sea               Drama
# 18829                                      Veronica Mars              Comedy
# 9844                                         Miles Ahead               Drama
# 18518                                Two Girls and a Guy              Comedy
# 4989                              Everybody Wants Some!!              Comedy
# 4768                                         El Mariachi              Action
# 6357                                             Gun Shy        Crime Comedy
# 1709                                          Bamboozled              Comedy
# 9494                               Margot at the Wedding      Comedy / Drama
# 9344                                       Maggie's Plan              Comedy
# 5452                                             Flipped              Comedy
# 3376                                        Clay Pigeons        Crime Comedy
# 13390                             Smilla's Sense of Snow    Drama / Thriller
# 9400                                            Mallrats              Comedy
# 19122                              Welcome to Collinwood        Crime Comedy
# 9525                                        Married Life        Crime Comedy
# 19656                                         Young Adam      Crime Thriller
# 12997                                  Shadow Conspiracy            Thriller
# 5123                                            Faithful              Comedy
# 7889                                        Jimmy's Hall    Historical Drama
# 11937                                        Quinceanera               Drama
# 16276                                 The Leisure Seeker               Drama
# 7384                                  Imagine Me and You     Romantic Comedy
# 15562                                   The Front Runner               Drama
# 19211                  When Did You Last See Your Father               Drama
# 19721                                        Zero Effect     Comedy Thriller
# 18024                                      Thoroughbreds    Drama / Thriller
# 19686                                Youth Without Youth               Drama
# 12077                                         Raw (2017)              Horror
# 734                                                 Adam      Comedy / Drama
# 12169                                            Redbelt        Action Drama
# 12076                                           Ravenous       Period Horror
# 1461                                        Ask the Dust   Romantic Thriller
# 18147                                              Titus       Fantasy Drama
# 2925                                      Captive (2015)            Thriller
# 3690                                    Crazy in Alabama      Comedy / Drama
# 14936                             The Broken Hearts Club     Romantic Comedy
# 15337                                           The East               Drama
# 15677                                       The Good Lie               Drama
# 17046                                         The Raid 2    Foreign / Action
# 5208                                    Fast Food Nation      Comedy / Drama
# 18429                                              Truth               Drama
# 4764                                         El Jeremias      Comedy / Drama
# 9945                                    Mistress America              Comedy
# 13849                                              Steel  Action / Adventure
# 1153                                             Amreeka              Comedy
# 11696                                        Poster Boys              Comedy
# 18065                                        Thumbsucker      Comedy / Drama
# 4812                                                Elle    Drama / Thriller
# 6010                                           Girlfight        Sports Drama
# 17113                                          The Rider               Drama
# 9168                                     Love is Strange               Drama
# 9730                               Men, Women & Children               Drama
# 1523                                          Austenland     Romantic Comedy
# 16296                              The Limits of Control         Crime Drama
# 9489                                             Marci X              Comedy
# 1459                                 Ashes of Time Redux    Foreign / Action
# 4872                                       Enduring Love    Drama / Thriller
# 1292                                       Another Earth               Drama
# 12238                                   Reservation Road               Drama
# 9072                                          Lost River               Drama
# 1481                                              Asylum   Romantic Thriller
# 18116                                          Time Code               Drama
# 10749                                          Northfork       Fantasy Drama
# 4137                                          Demolition               Drama
# 13060                                        She Hate Me      Comedy / Drama
# 369                                    A Fantastic Woman               Drama
# 5029                                     Excessive Force              Action
# 11035                             Only Lovers Left Alive               Drama
# 15271                        The Diary of a Teenage Girl               Drama
# 19595                                    Year of the Dog               Drama
# 7426                                       In My Country               Drama
# 13520                                        Son of Saul               Drama
# 7590                                           Interview               Drama
# 7256                                     I Saw the Light               Drama
# 15088                                       The Comedian              Comedy
# 6320                                              Groove         Music Drama
# 14840                                The Blood of Heroes       Sci-Fi Action
# 2331                                      Blood and Wine         Crime Drama
# 1657                                            Bad Moon              Horror
# 6699                                             Heights               Drama
# 2898                                           Capernaum               Drama
# 17386                                      The Statement    Drama / Thriller
# 18205                                       Toni Erdmann      Comedy / Drama
# 7531                               Infinitely Polar Bear      Comedy / Drama
# 11345                                        Patti Cake$               Drama
# 11180                                     Owning Mahowny         Crime Drama
# 8920                                    Little Manhattan     Romantic Comedy
# 9481                                   Maps to the Stars               Drama
# 5534                            For a Good Time, Call...              Comedy
# 14044                                              Sugar        Sports Drama
# 16039                                The Invisible Woman               Drama
# 10526                                    Never Look Away               Drama
# 9651                                          Mean Creek    Drama / Thriller
# 4622                                                Duma    Family Adventure
# 3850                                 Damsels in Distress              Comedy
# 10938                                     On a Clear Day               Drama
# 2238                                           Black Sea            Thriller
# 1168                                An American Rhapsody               Drama
# 19463                                     Without Limits        Sports Drama
# 14946                               The Brothers Solomon              Comedy
# 9154                         Love and Other Catastrophes     Romantic Comedy
# 14409                                             Tekken              Action
# 14746                              The Beautiful Country               Drama
# 15003                            The Caveman's Valentine    Drama / Thriller
# 8213                                  Kill Your Darlings               Drama
# 3926                                   Darling Companion              Comedy
# 238                                         5 Flights Up               Drama
# 2349                                       Bloody Sunday    Historical Drama
# 16444                                  The Man Who Cried           War Drama
# 3127                                      Charlotte Gray           War Drama
# 5320                   Film Stars Don't Die in Liverpool               Drama
# 17185                                     The Salton Sea      Crime Thriller
# 17277                                The Shape of Things               Drama
# 16821                           The Passenger (re-issue)               Drama
# 6857                                       Higher Ground               Drama
# 11732                                        Prefontaine        Sports Drama
# 4581                                     Driving Lessons      Comedy / Drama
# 16981                 The Prize Winner of Defiance, Ohio        Period Drama
# 3861                               Dancer, Texas Pop. 81      Comedy / Drama
# 7954                                              Joshua    Drama / Thriller
# 9808                                          Middle Men        Crime Comedy
# 14194                                         Swept Away     Romantic Comedy
# 15485                                   The First Grader               Drama
# 18255                                      Touch of Pink              Comedy
# 17696                                  The Virginity Hit              Comedy
# 7292                            I'll Sleep When I'm Dead         Crime Drama
# 2499                                       Bottle Rocket        Crime Comedy
# 14938                                         The Bronze              Comedy
# 17297                                  The Signal (2014)     Sci-Fi Thriller
# 7253                                           I Origins               Drama
# 7342                                           Idiocracy       Sci-Fi Comedy
# 5600                                             Foxtrot               Drama
# 16220                                      The Last Shot              Comedy
# 602                          A Tale of Love and Darkness               Drama
# 1942                                         Being Flynn      Comedy / Drama
# 5764                                          Full of It              Comedy
# 9187                                     Loveless (2018)               Drama
# 11124                                  Our Little Sister               Drama
# 12060                                           Rapa Nui    Period Adventure
# 17034                                          The Quiet            Thriller
# 15800                                   The Happy Prince               Drama
# 13118                                      Shooting Fish     Romantic Comedy
# 5333                                      Final Portrait      Comedy / Drama
# 13565                                  Sound of My Voice               Drama
# 16479                          The Marc Pease Experience              Comedy
# 8537                                        Land of Mine           War Drama
# 749                                            Adoration               Drama
# 19443                                    Winter Solstice               Drama
# 10513                                        Never Again     Romantic Comedy
# 13384                                            Smashed      Comedy / Drama
# 1482                                        At Any Price           Adventure
# 7381                                    Imaginary Heroes               Drama
# 9491                                            Margaret               Drama
# 649                     A Woman, A Gun and A Noodle Shop               Drama
# 19415                                         Wind Chill              Horror
# 15523                                  The Foot Fist Way              Comedy
# 8992                                         Lola Versus              Comedy
# 1002                                               Aloft               Drama
# 10791                                           November            Thriller
# 18430                        Truth or Consequences, N.M.      Action / Crime
# 8656                                      League of Gods      Action Fantasy
# 12259                                    Restless (2011)               Drama
# 65                                            13 Minutes               Drama
# 1678                                             Baghead       Horror Comedy
# 8188                                               Kicks               Drama
# 3619                                             Cop Car            Thriller
# 5895                                   Gentlemen Broncos              Comedy
# 1757                                        Barely Legal              Comedy
# 1162            An Alan Smithee Film:Burn Hollywood Burn              Comedy
# 5636                                    Freaks of Nature              Comedy
# 18969                                      Walk of Shame     Romantic Comedy
# 10163                                          Mr. Right       Action Comedy
# 14439                                          Term Life         Crime Drama
# 9203                                        Loving Pablo         Crime Drama
# 698                                          Abracadabra      Comedy / Drama
# 1389                                             Area 51              Horror
# 11092                                                Oro           Adventure
# 12861                                       Search Party              Comedy
# 4599                                       Drunk Wedding              Comedy
# 4772                                            El Pacto     Horror Thriller
#
#        worldwide_adj
# 1543    3.256402e+09
# 15395   2.458814e+09
# 7815    2.196843e+09
# 4660    2.063268e+09
# 1548    2.048360e+09
# 8021    1.797145e+09
# 8025    1.758983e+09
# 9540    1.661126e+09
# 5784    1.607589e+09
# 15649   1.542585e+09
# 1547    1.488951e+09
# 2233    1.347586e+09
# 11550   1.328002e+09
# 7649    1.309772e+09
# 8027    1.309484e+09
# 7507    1.308190e+09
# 15446   1.265601e+09
# 18319   1.254529e+09
# 13315   1.213508e+09
# 2909    1.206643e+09
# 15193   1.186325e+09
# 901     1.180898e+09
# 18318   1.171075e+09
# 15190   1.170337e+09
# 11552   1.167366e+09
# 11549   1.166776e+09
# 14119   1.156655e+09
# 5572    1.150311e+09
# 1366    1.147328e+09
# 13641   1.146951e+09
# 12479   1.104898e+09
# 13644   1.081329e+09
# 4661    1.062786e+09
# 13643   1.049410e+09
# 12002   1.046111e+09
# 17313   1.014084e+09
# 16087   1.011252e+09
# 16495   1.010368e+09
# 8005    9.856267e+08
# 12741   9.825211e+08
# 18320   9.788601e+08
# 16391   9.678790e+08
# 14443   9.603297e+08
# 7516    9.602247e+08
# 7499    9.580189e+08
# 15176   9.504078e+08
# 13621   9.324701e+08
# 9721    9.208673e+08
# 7515    9.174500e+08
# 6946    9.158291e+08
# 1792    9.140394e+08
# 17394   9.027202e+08
# 13647   9.016648e+08
# 1544    9.016537e+08
# 2413    8.993203e+08
# 1617    8.945507e+08
# 134     8.938553e+08
# 11553   8.928819e+08
# 6337    8.848531e+08
# 18022   8.748353e+08
# 11746   8.607688e+08
# 18313   8.586425e+08
# 18818   8.550140e+08
# 1401    8.536943e+08
# 5204    8.501270e+08
# 19505   8.415549e+08
# 1783    8.331662e+08
# 14602   8.289268e+08
# 4017    8.287014e+08
# 6335    8.189681e+08
# 18220   8.175071e+08
# 11551   8.142761e+08
# 7517    8.050258e+08
# 9931    7.967589e+08
# 19564   7.932616e+08
# 18507   7.923486e+08
# 1086    7.917788e+08
# 9928    7.911151e+08
# 4018    7.858637e+08
# 14052   7.809759e+08
# 9929    7.755320e+08
# 19013   7.705385e+08
# 10180   7.668514e+08
# 2055    7.645114e+08
# 7816    7.640747e+08
# 6258    7.636417e+08
# 2911    7.576235e+08
# 3954    7.537841e+08
# 14603   7.520284e+08
# 3724    7.519544e+08
# 2995    7.432731e+08
# 9927    7.325096e+08
# 15205   7.315149e+08
# 6450    7.281308e+08
# 9930    7.232997e+08
# 9423    7.200691e+08
# 12426   7.199395e+08
# 10600   7.186488e+08
# 7648    7.169047e+08
# 7680    7.159908e+08
# 5970    7.134737e+08
# 7588    7.127104e+08
# 7193    7.089024e+08
# 4371    7.083747e+08
# 8250    7.078278e+08
# 5225    7.076152e+08
# 5206    7.012257e+08
# 12035   7.010469e+08
# 19313   7.000514e+08
# 16494   6.986342e+08
# 18023   6.947908e+08
# 11906   6.868216e+08
# 9680    6.867295e+08
# 9265    6.824982e+08
# 7647    6.824847e+08
# 8057    6.729802e+08
# 8830    6.725866e+08
# 1619    6.722681e+08
# 2697    6.612449e+08
# 15790   6.548574e+08
# 4659    6.538143e+08
# 6948    6.425240e+08
# 10857   6.390721e+08
# 2056    6.373057e+08
# 8984    6.341409e+08
# 1774    6.316643e+08
# 18412   6.304636e+08
# 17328   6.293324e+08
# 15565   6.278466e+08
# 16587   6.272542e+08
# 3000    6.247509e+08
# 1306    6.229094e+08
# 18321   6.202125e+08
# 9724    6.166970e+08
# 16590   6.153991e+08
# 10129   6.148554e+08
# 3529    6.129140e+08
# 3122    6.112419e+08
# 13085   6.089025e+08
# 2282    6.086671e+08
# 14386   6.044799e+08
# 4264    6.032198e+08
# 9023    6.014414e+08
# 13083   5.983784e+08
# 16486   5.957467e+08
# 15506   5.931439e+08
# 14446   5.914267e+08
# 16497   5.831711e+08
# 6098    5.815625e+08
# 12092   5.810902e+08
# 1119    5.806047e+08
# 8342    5.804932e+08
# 16511   5.794232e+08
# 19529   5.775032e+08
# 8774    5.740126e+08
# 19566   5.721647e+08
# 1241    5.716566e+08
# 13197   5.698532e+08
# 17936   5.698198e+08
# 1347    5.693078e+08
# 19563   5.690910e+08
# 17108   5.646265e+08
# 6100    5.611935e+08
# 12807   5.598024e+08
# 19567   5.564088e+08
# 1788    5.545249e+08
# 10470   5.539035e+08
# 196     5.511791e+08
# 1305    5.499434e+08
# 10789   5.483491e+08
# 15788   5.461648e+08
# 19183   5.455357e+08
# 10457   5.453489e+08
# 4184    5.440619e+08
# 12950   5.393064e+08
# 4091    5.383621e+08
# 17145   5.370490e+08
# 14884   5.370322e+08
# 1067    5.369972e+08
# 13623   5.368201e+08
# 903     5.336210e+08
# 12383   5.318143e+08
# 11185   5.317464e+08
# 16505   5.298872e+08
# 14399   5.232813e+08
# 8024    5.208456e+08
# 1032    5.186777e+08
# 11575   5.135737e+08
# 33      5.132398e+08
# 8023    5.108525e+08
# 3726    5.085951e+08
# 5428    5.079208e+08
# 13754   5.037959e+08
# 7097    5.032951e+08
# 18245   5.021352e+08
# 19009   5.021280e+08
# 18019   5.015985e+08
# 9872    5.005374e+08
# 9932    4.955502e+08
# 12059   4.946861e+08
# ...              ...
# 14462   4.486187e+06
# 9512    4.478918e+06
# 8012    4.469576e+06
# 2598    4.451214e+06
# 17779   4.440498e+06
# 12920   4.438439e+06
# 3671    4.373553e+06
# 7677    4.343845e+06
# 14115   4.241034e+06
# 6549    4.234407e+06
# 13151   4.195362e+06
# 1424    4.118639e+06
# 12559   4.065034e+06
# 7835    4.055984e+06
# 16581   4.040559e+06
# 8874    3.916160e+06
# 17701   3.793657e+06
# 1532    3.774821e+06
# 3045    3.763697e+06
# 2796    3.741264e+06
# 18829   3.713745e+06
# 9844    3.620508e+06
# 18518   3.566376e+06
# 4989    3.557536e+06
# 4768    3.548390e+06
# 6357    3.543118e+06
# 1709    3.527155e+06
# 9494    3.509405e+06
# 9344    3.506748e+06
# 5452    3.480741e+06
# 3376    3.476378e+06
# 13390   3.476375e+06
# 9400    3.473922e+06
# 19122   3.449688e+06
# 9525    3.419290e+06
# 19656   3.405458e+06
# 12997   3.370842e+06
# 5123    3.368001e+06
# 7889    3.354837e+06
# 11937   3.313209e+06
# 16276   3.305248e+06
# 7384    3.282458e+06
# 15562   3.242235e+06
# 19211   3.210196e+06
# 19721   3.205378e+06
# 18024   3.187302e+06
# 19686   3.178784e+06
# 12077   3.172454e+06
# 734     3.150931e+06
# 12169   3.114695e+06
# 12076   3.108551e+06
# 1461    3.064174e+06
# 18147   3.025478e+06
# 2925    2.968050e+06
# 3690    2.945461e+06
# 14936   2.944340e+06
# 15337   2.926242e+06
# 15677   2.887460e+06
# 17046   2.786693e+06
# 5208    2.751866e+06
# 18429   2.692960e+06
# 4764    2.657622e+06
# 9945    2.649075e+06
# 13849   2.638468e+06
# 1153    2.547277e+06
# 11696   2.526920e+06
# 18065   2.467608e+06
# 4812    2.449827e+06
# 6010    2.429450e+06
# 17113   2.419031e+06
# 9168    2.399551e+06
# 9730    2.376546e+06
# 1523    2.327255e+06
# 16296   2.301793e+06
# 9489    2.267039e+06
# 1459    2.230529e+06
# 4872    2.224764e+06
# 1292    2.165528e+06
# 12238   2.159579e+06
# 9072    2.129112e+06
# 1481    2.114240e+06
# 18116   2.087317e+06
# 10749   2.077736e+06
# 4137    2.070099e+06
# 13060   2.023714e+06
# 369     2.020988e+06
# 5029    2.002108e+06
# 11035   1.993631e+06
# 15271   1.990150e+06
# 19595   1.942770e+06
# 7426    1.917611e+06
# 13520   1.882683e+06
# 7590    1.762592e+06
# 7256    1.722950e+06
# 15088   1.699220e+06
# 6320    1.698489e+06
# 14840   1.695097e+06
# 2331    1.694933e+06
# 1657    1.689291e+06
# 6699    1.679551e+06
# 2898    1.661096e+06
# 17386   1.576720e+06
# 18205   1.547807e+06
# 7531    1.515703e+06
# 11345   1.512792e+06
# 11180   1.492555e+06
# 8920    1.437366e+06
# 9481    1.417927e+06
# 5534    1.369038e+06
# 14044   1.339519e+06
# 16039   1.330416e+06
# 10526   1.304042e+06
# 9651    1.297874e+06
# 4622    1.279051e+06
# 3850    1.275667e+06
# 10938   1.267065e+06
# 2238    1.241205e+06
# 1168    1.205562e+06
# 19463   1.202119e+06
# 14946   1.172311e+06
# 9154    1.162783e+06
# 14409   1.132267e+06
# 14746   1.129306e+06
# 15003   1.119915e+06
# 8213    1.110318e+06
# 3926    1.090507e+06
# 238     1.081612e+06
# 2349    1.079283e+06
# 16444   1.059289e+06
# 3127    1.051210e+06
# 5320    1.051187e+06
# 17185   1.005860e+06
# 17277   1.004417e+06
# 16821   9.663790e+05
# 6857    9.401910e+05
# 11732   9.243510e+05
# 4581    9.158410e+05
# 16981   8.859180e+05
# 3861    8.855570e+05
# 7954    8.719360e+05
# 9808    8.686310e+05
# 14194   8.355970e+05
# 15485   7.978680e+05
# 18255   7.724030e+05
# 17696   7.332120e+05
# 7292    6.526440e+05
# 2499    6.521550e+05
# 14938   6.442970e+05
# 17297   6.373730e+05
# 7253    6.305210e+05
# 7342    6.200450e+05
# 5600    6.188830e+05
# 16220   6.168030e+05
# 602     5.986760e+05
# 1942    5.907640e+05
# 5764    5.894580e+05
# 9187    5.663560e+05
# 11124   5.566000e+05
# 12060   5.169040e+05
# 17034   4.750850e+05
# 15800   4.664400e+05
# 13118   4.655550e+05
# 5333    4.619720e+05
# 13565   4.579670e+05
# 16479   4.571630e+05
# 8537    4.553960e+05
# 749     4.499860e+05
# 19443   4.340910e+05
# 10513   4.310180e+05
# 13384   4.118840e+05
# 1482    4.102470e+05
# 7381    3.868240e+05
# 9491    3.738530e+05
# 649     3.595860e+05
# 19415   3.452290e+05
# 15523   2.796650e+05
# 8992    2.762720e+05
# 1002    2.518180e+05
# 10791   2.466870e+05
# 18430   1.909450e+05
# 8656    1.900330e+05
# 12259   1.822580e+05
# 65      1.654760e+05
# 1678    1.633000e+05
# 8188    1.571370e+05
# 3619    1.521980e+05
# 5895    1.395470e+05
# 1757    1.072820e+05
# 1162    8.141700e+04
# 5636    7.517600e+04
# 18969   6.280300e+04
# 10163   3.629900e+04
# 14439   2.223900e+04
# 9203    2.201700e+04
# 698     1.431600e+04
# 1389    8.005000e+03
# 11092   5.674000e+03
# 12861   4.782000e+03
# 4599    3.497000e+03
# 4772    2.488000e+03
#
# [2892 rows x 3 columns]

# %%
grp = data[data['worldwide_adj'] >= 1000000000][genres]
grp.sum().plot(kind='pie')

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Dollars Earned For Every Dollar Spent (Includes Marketing)', fontsize=20, y=1.02)

summary.sort_values('dollars_earned_for_dollars_spent', ascending=False, inplace=True)

summary.plot(y=['dollars_earned_for_dollars_spent', 'mean_dollars_earned_for_dollars_spent', 'median_dollars_earned_for_dollars_spent'], kind='bar', ax=axis, color=colors[0:3], legend=True)
axis.set_ylabel('Dollars', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
axis.legend(['All-Time', 'Mean', 'Median'], fontsize=20)
autolabel(axis, num_decimals=1)

plt.tight_layout()

# %% [markdown]
# # Initial Thoughts
#
#
# - All-time, `Action` movies have made the most money, followed by `Comedy` then `Adventure`
# - Our dataset in general and separated by genre is heavily skewed to the right. We can see we have much higher mean grosses than median grosses. This fits with our understanding of the movie business -- there are a few megahits that earn make many multiples
#
#
# **Number of movies**
#   - `Comedy` and `Drama` are historically the most produced genres by big movie studios by a healthy margin
#   - They have been the top two spots for the last four decades
#
#
# **Average worldwide gross**
#   - `Adventure` and `Action` historically gross the highest average amount per movie
#   - `Adventure` has an average worldwide gross that is more than double the genre in third place
#   - Perhaps surprisingly, `Horror` is in third place
#   - The means are skewed by really high-grossing movies in each genre, as the means are much higher than medians
#
#
# **All-Time Gross Per Genre**
#   - In aggregate, `Action`, `Comedy`, then `Adventure` have grossed the most money worldwide
#   - `Action` is ahead of `Comedy` by almost \\$16 billion dollars
#
#
# **Average production budget**
#   - `Adventure` and `Action` have by far the largest average production budget. This makes sense, as those movies tend to require more setpieces and CGI than other genres
#   - Both `Adventure` and `Action` are at least double the average production budget of the third place genre, `Thriller/Suspense`
#   - `Comedy`, `Horror`, and `Drama` all have very similar, low average production budgets
#   - There aren't huge outliers with production budgets as the medians and means are very consistent for all genres. This cap indicates there are spending thresholds that studios don't pass on production budgets.
#
#
# **Dollar earned for every dollar spent**
#   - `Horror` earns a studio approximately 1.4 dollars for every dollar spent
#   - `Adventure`, `Action`, and `Comedy` are all tied for second place with 1.1 dollars earned per dollar spent
#   - Except `Thriller/Suspense`, every genre in aggregate is at least breakeven on a dollar for dollar basis
#
#
# **Summing up**
#
# `Action`, `Comedy`, and `Adventure` have made the most overall money worldwide. `Action` and `Adventure` have far higher average worldwide grosses than `Comedy`. `Comedy` must be making up for this with its higher numbers of movies released. However, `Adventure` and `Action` are the two most expensive genres to make, whereas `Comedy` is fourth.
#
# The best return for every dollar spent in aggregate come from `Horror` and `Adventure`.
#
# When taking into account our domestic box office analysis, now we see the reason `Action` and `Adventure` movies are made. They were net losers domestically, but make up for this with much higher worldwide grosses.
# - `Action`:
#   - Average domestic gross: \\$116 million
#   - Average worldwide gross: \\$297 million
#
# - `Adventure`:
#   - Average domestic gross: \\$151 million
#   - Average worldwide gross: \\$387 million
#
# That's a difference of \\$181 million and \\$236 million respectively!
#
# There are a couple strategies our bosses can consider:
#
# 1) Go for the safest genre. Our bosses are less likely to lose big money on `Horror`. It's one the cheapest genres to produce and has the highest average dollar earned per dollar spent.
#
# 2) Swing for the fences. If they can afford to be risky, `Adventure` and `Action` historically have the highest earnings potential. This is probably due to their ability to travel well and be unimpeded by language barriers. Anyone in the world can watch a fight scene, car chase, or explosion and understand what's happening.
#
# Let's look at each genre's performance by decade to see if there are recent trends we can spot.

# %% [markdown]
# # Performance By Decade

# %% [markdown]
# ## All Decades

# %% [markdown]
# ### Worldwide Gross

# %%
# Create variables for first_axes, secondary_axes, and counter variables 
ax1, ax2, ax3, ax4, ax5, ax6 = 'abcdef'
first_axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

ax1_1, ax2_1, ax3_1, ax4_1, ax5_1, ax6_1 = 'abcdef'
second_axes_list = [ax1_1, ax2_1, ax3_1, ax4_1, ax5_1, ax6_1]

# Counters to keep track of iteration
counters = [0, 1, 2, 3, 4, 5]

for genre, first_axis, second_axis, color, count in zip(genres, first_axes_list, second_axes_list, colors, counters):
        figure, first_axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 10))
        second_axis = figure.add_axes()

        # Only write the title once
        if count == 0:
            figure.suptitle('Mean Worldwide Gross By Genre And Decade\n(Counts Labeled)', fontsize=20, y=1.02)

        grp = (data[data[genre]].groupby('release_decade').mean() / 1000000)['worldwide_adj'].copy()
        grp_counts = data[data[genre]].groupby('release_decade')['worldwide_adj'].count().copy()
    
        # If the series is missing a decade, add it as an index and set the value to zero
        for decade in range(1910, 2020, 10):
            if decade not in grp.index:
                grp.loc[decade] = 0
                grp_counts.loc[decade] = 0

        # Sort the series by its index to have the decades in chronological order                
        grp.sort_index(ascending=True, inplace=True)
        grp_counts.sort_index(ascending=True, inplace=True)
        
        # Set up y-axis    
        first_axis = grp.plot(kind='bar', xticks=range(1910, 2020, 10), linewidth=3, color=color)
        first_axis.set_ylabel('Worldwide Gross In Millions', fontsize=12)
        first_axis.set_ylim(0,900)
        first_axis.legend([genre], loc=2, fontsize=15)
        
        autolabel(first_axis, counts=grp_counts.values)
        
        # Set up second y-axis
        second_axis = first_axis.twinx()
        second_axis.plot(first_axis.get_xticks(), grp_counts.values, linewidth=3, color='k')
        second_axis.set_ylabel('Number of Movies', fontsize=12)
        second_axis.set_ylim(0,600)
        second_axis.legend(['counts'], loc=1, fontsize=15)
        
        # Only show graphs when on the last one
        if count == len(counters) - 1:
            plt.tight_layout()

# %% [markdown]
# Key Takeaways:
#
# **1970s were the best!**
# - Either our dataset only has big winners from the 1970s, or we should have stopped making movies after then! We have far fewer movies from the 1970s in our dataset, but the average worldwide grosses there are way higher than any other decade. We should be cautious in drawing conclusions there without investigating this closer.
#
# **Changes since the 1990s**
# - `Action` and `Adventure` have by far the biggest increases in average worldwide gross. The other genres all earn less on average than they did in the 1990s.
# - Every genre had a big jump in the number of movies released from the 1990s to the 2000s.
# - Only `Action` has had more movies released from the 2000s to the 2010s. Every other genre has had a steep decline in output.
#
# **Horror and Thriller/Suspense comeback**
# - Though much smaller than the increase in `Action` and `Adventure` grosses, `Horror` and `Thriller/Suspense` have had their average gross increase from the 2000s to the 2010s.
#
# **Fewer movies made now**
# - Our gut should tell us movies are not as profitable now as they used to be because the Big Five release far fewer movies now than they did in the 2000s.

# %% [markdown]
# ### Production Budget

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Mean Production Budget By Genre And Release Decade', fontsize=20, y=1.02)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # We must replace missing decades with zeroes to have the bar plots xticks line up
    
    # Create a series with decades as indexes and domestic gross as values
    grp = (data[data[genre]].groupby('release_decade').mean() / 1000000)['budget_adj'].copy()
    
    # If the series is missing a decade, add it as an index and set the value to zero
    for decade in range(1910, 2020, 10):
        if decade not in grp.index:
            grp.loc[decade] = 0
    
    # Sort the series by its index to have the decades in chronological order                
    grp.sort_index(ascending=True, inplace=True)
        
    grp.plot(kind='bar', xticks=range(1910, 2020, 10), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Production Budget In Millions', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    autolabel(axis)

plt.tight_layout()

# %% [markdown]
# Key Takeaways:
# - Production budgets for Action and Adventure have been increasing since the 1980s
# - Production budgets for all other genres have declined since the 1990s
# - This is probably due to the heavy use of expensive CGI in Action and Adventure movies, which has only increased over time. Meanwhile, technological advancements have decreased the overall cost of producing movies in general.

# %% [markdown]
# ### Worldwide Breakeven Percentage

# %%
# Create new column on summary dataframe to hold the most recent breakeven percentage by genre
summary['2010s_breakeven_percent'] = np.nan

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Worldwide Breakeven Percentage By Decade\n(Counts Labeled)', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_count = data[data[genre]].groupby('release_decade')['worldwide_breakeven'].count().copy()
    grp_sum = data[data[genre]].groupby('release_decade')['worldwide_breakeven'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for decade in range(1910, 2020, 10):
        if decade not in grp_count.index:
            grp_count.loc[decade] = 0
            grp_sum.loc[decade] = 0

    # Sort the series by their index to have the decades in chronological order                
    grp_count.sort_index(ascending=True, inplace=True)
    grp_sum.sort_index(ascending=True, inplace=True)
    
    summary.loc[genre, ['2010s_breakeven_percent']] = round((grp_sum / grp_count * 100).loc[2010],1)

    (grp_sum / grp_count * 100).plot(kind='bar', xticks=range(2010, 2019, 1), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Percentage', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the count of how many movies breakeven above each bar
    autolabel(axis, counts=grp_count.values)
    
plt.tight_layout()

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('2010s Breakeven Percentage By Genre', fontsize=20, y=1.02)

summary.sort_values('2010s_breakeven_percent', ascending=False, inplace=True)

summary.plot(y='2010s_breakeven_percent', kind='bar', ax=axis, color=colors[0], legend=False)
axis.set_ylabel('Percentage', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
autolabel(axis, num_decimals=1)

plt.tight_layout()

# %% [markdown]
# ### Quick Thoughts
#
# **Movies are more risky now**
#   - From the 1960s to 1990s, for most genres, there was an overall decrease in a movie's probability of breaking even
#   - Such a decrease went alongside a huge increase in the numbers of movies released overall
#   - The market might have gotten oversaturated, at which point the same amount of consumer dollars could not support the increase in movies
#
#   - From the 1990s to the 2010s, every genre has seen an increase in a movie's probability of breaking even
#   - This reduction in output coincides with an increase in a genre's probability of success
#   - It could be that a huge contributor to a movie's ultimate success is just the number of movies it has to compete with
#
# **Safest current genres**
#   - `Horror` is by far the safest domestic release genre
#   - `Thriller/Suspense`, and `Comedy` are the next safest from a breakeven perspective
#   - `Action` and `Adventure` have very little chance of breaking even in just the domestic market

# %%
figure, axis = plt.subplots(nrows=1, ncols=1, figsize=(24, 9))
figure.suptitle('Number of Movies Released By Decade and Genre', fontsize=20, y=1.02)

grp = data.groupby('release_decade')['action', 'adventure', 'comedy', 'drama', 'horror', 'thriller_suspense'].sum()

grp.plot(kind='bar', stacked=True, ax=axis)
axis.set_ylabel('Number of Movies', fontsize=20)
axis.set_xlabel('')
axis.tick_params(labelsize=20)
axis.legend(fontsize=20)

plt.tight_layout()

# %% [markdown]
# # Stacked Chart Worldwide Gross By Decade

# %% [markdown]
# # Extras

# %%
# Create worldwide gross by genre columns
def breakeven_by_genre(row, genre):
    if row[genre] is False:
        return np.nan
    
    if row['worldwide_breakeven'] is False:
        return 0
    else:
        return 1
    
# List of new columns to hold worldwide grosses by genre
breakeven_columns = ['breakeven_{}'.format(genre) for genre in genres]

for genre, col in zip(genres, breakeven_columns):
    data[col] = data.apply(lambda x: breakeven_by_genre(x, genre), axis=1)

# %% [markdown]
# ### Only Looking At Movies With A Production Budget

# %%
has_budget = data[data['budget_adj'].notna()].copy()
has_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2453 entries, 20 to 19775
# Data columns (total 35 columns):
# title                                2453 non-null object
# release_year                         2453 non-null int64
# distributor_mojo                     2453 non-null object
# genres_mojo                          2453 non-null object
# release_date                         2453 non-null datetime64[ns]
# worldwide_adj                        2453 non-null float64
# budget_adj                           2453 non-null float64
# release_week                         2453 non-null int64
# release_decade                       2453 non-null int64
# worldwide_breakeven                  2453 non-null bool
# action                               2453 non-null bool
# adventure                            2453 non-null bool
# comedy                               2453 non-null bool
# drama                                2453 non-null bool
# horror                               2453 non-null bool
# thriller_suspense                    2453 non-null bool
# universal                            2453 non-null bool
# paramount                            2453 non-null bool
# warner                               2453 non-null bool
# disney                               2453 non-null bool
# sony                                 2453 non-null bool
# distributor                          2453 non-null object
# profit                               2453 non-null float64
# worldwide_gross_action               480 non-null float64
# worldwide_gross_adventure            251 non-null float64
# worldwide_gross_comedy               959 non-null float64
# worldwide_gross_drama                664 non-null float64
# worldwide_gross_horror               254 non-null float64
# worldwide_gross_thriller_suspense    352 non-null float64
# breakeven_action                     480 non-null float64
# breakeven_adventure                  251 non-null float64
# breakeven_comedy                     959 non-null float64
# breakeven_drama                      664 non-null float64
# breakeven_horror                     254 non-null float64
# breakeven_thriller_suspense          352 non-null float64
# dtypes: bool(12), datetime64[ns](1), float64(15), int64(3), object(4)
# memory usage: 488.7+ KB

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Dollars Earned For Every Dollar Spent By Decade (Includes Marketing)\n(Percentages Labeled)', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_gross_count = has_budget[has_budget[genre]].groupby('release_decade')['domestic_adj'].count().copy()
    grp_gross_sum = has_budget[has_budget[genre]].groupby('release_decade')['domestic_adj'].sum().copy()
    
    grp_budget_count = has_budget[has_budget[genre]].groupby('release_decade')['budget_adj'].count().copy()
    grp_budget_sum = has_budget[has_budget[genre]].groupby('release_decade')['budget_adj'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for decade in range(1910, 2020, 10):
        if decade not in grp_gross_count.index:
            grp_gross_count.loc[decade] = 0
            grp_gross_sum.loc[decade] = 0
        
        if decade not in grp_budget_count.index:
            grp_budget_count.loc[decade] = 0
            grp_budget_sum.loc[decade] = 1

    # Sort the series by their index to have the decades in chronological order                
    grp_gross_count.sort_index(ascending=True, inplace=True)
    grp_gross_sum.sort_index(ascending=True, inplace=True)
    grp_budget_count.sort_index(ascending=True, inplace=True)
    grp_budget_sum.sort_index(ascending=True, inplace=True)
    
    dollars_earned_to_dollars_spent = round((grp_gross_sum / (1.5 * grp_budget_sum)), 1)
            
    dollars_earned_to_dollars_spent.plot(kind='bar', xticks=range(1910, 2020, 10), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Dollars', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the percentage of how many movies breakeven above each bar
    autolabel(axis, num_decimals=1)
    
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-1a383d888146> in <module>
#       7 for genre, axis, color in zip(genres, axes_list, colors):
#       8     # Create two series with decades as indexes and count and sum as values
# ----> 9     grp_gross_count = has_budget[has_budget[genre]].groupby('release_decade')['domestic_adj'].count().copy()
#      10     grp_gross_sum = has_budget[has_budget[genre]].groupby('release_decade')['domestic_adj'].sum().copy()
#      11
#
# C:\Users\Colin\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: domestic_adj'

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Dollars Earned For Every Dollar Spent By Decade (Includes Marketing)\n(Counts Labeled)', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_gross_count = has_budget[has_budget[genre]].groupby('release_decade')['domestic_adj'].count().copy()
    grp_gross_sum = has_budget[has_budget[genre]].groupby('release_decade')['domestic_adj'].sum().copy()
    
    grp_budget_count = has_budget[has_budget[genre]].groupby('release_decade')['budget_adj'].count().copy()
    grp_budget_sum = has_budget[has_budget[genre]].groupby('release_decade')['budget_adj'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for decade in range(1910, 2020, 10):
        if decade not in grp_gross_count.index:
            grp_gross_count.loc[decade] = 0
            grp_gross_sum.loc[decade] = 0
        
        if decade not in grp_budget_count.index:
            grp_budget_count.loc[decade] = 0
            grp_budget_sum.loc[decade] = 1

    # Sort the series by their index to have the decades in chronological order                
    grp_gross_count.sort_index(ascending=True, inplace=True)
    grp_gross_sum.sort_index(ascending=True, inplace=True)
    grp_budget_count.sort_index(ascending=True, inplace=True)
    grp_budget_sum.sort_index(ascending=True, inplace=True)
    
    dollars_earned_to_dollars_spent = round((grp_gross_sum / (1.5 * grp_budget_sum)), 1)
            
    dollars_earned_to_dollars_spent.plot(kind='bar', xticks=range(1910, 2020, 10), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Dollars', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the count of how many movies breakeven above each bar
    autolabel(axis, counts=grp_gross_count.values)
    
plt.tight_layout()

# %% [markdown]
# ### Quick Takeaways
#
# **Recent data is more reliable**
#   - We don't have many movies before the 1970s, so drawing conclusions there seems risky. For example, the huge spike in `Horror` in 1950 is due to a single movie.
#   - We should be able to trust the more recent data as there are far more movies available.
#
# **Last three decades**
#   - `Horror`, `Comedy`, and `Drama` are the best dollar for dollar movies.

# %% [markdown]
# ## Current Decade

# %%
current = data[data['release_year'] >= 2010].copy()

figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Percentage of Movies That Breakeven This Decade\n (Counts are labeled)', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_count = current[current[genre]].groupby('release_year')['domestic_breakeven'].count().copy()
    grp_sum = current[current[genre]].groupby('release_year')['domestic_breakeven'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for year in range(2010, 2019, 1):
        if year not in grp_count.index:
            grp_count.loc[year] = 0
            grp_sum.loc[year] = 0

    # Sort the series by their index to have the decades in chronological order                
    grp_count.sort_index(ascending=True, inplace=True)
    grp_sum.sort_index(ascending=True, inplace=True)

    (grp_sum / grp_count * 100).plot(kind='bar', xticks=range(2010, 2019, 1), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Percentage', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the count of how many movies breakeven above each bar
    autolabel(axis, counts=grp_count.values)
    
plt.tight_layout()

# %% [markdown]
# ### Quick Thoughts
#
# **Year by year takeaways**
#   - There is a great deal of variety in box office results on a year by year basis
#   - For the past decade, the strongest performing genre from a breakeven perspective appears to be `Horror`
#   - `Thriller/Suspense` is the next best option

# %%
current_with_budget = data[(data['release_year'] >= 2010) & (data['budget_adj'].notna())].copy()
current_with_budget.info()

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Dollars Earned For Every Dollar Spent This Decade (Includes Marketing)\n(Percentages Labeled)', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_gross_count = current_with_budget[current_with_budget[genre]].groupby('release_year')['domestic_adj'].count().copy()
    grp_gross_sum = current_with_budget[current_with_budget[genre]].groupby('release_year')['domestic_adj'].sum().copy()
    
    grp_budget_count = current_with_budget[current_with_budget[genre]].groupby('release_year')['budget_adj'].count().copy()
    grp_budget_sum = current_with_budget[current_with_budget[genre]].groupby('release_year')['budget_adj'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for year in range(2010, 2019, 1):
        if year not in grp_gross_count.index:
            grp_gross_count.loc[year] = 0
            grp_gross_sum.loc[year] = 0
        
        if year not in grp_budget_count.index:
            grp_budget_count.loc[year] = 0
            grp_budget_sum.loc[year] = 1

    # Sort the series by their index to have the decades in chronological order                
    grp_gross_count.sort_index(ascending=True, inplace=True)
    grp_gross_sum.sort_index(ascending=True, inplace=True)
    grp_budget_count.sort_index(ascending=True, inplace=True)
    grp_budget_sum.sort_index(ascending=True, inplace=True)
    
    dollars_earned_to_dollars_spent = round((grp_gross_sum / (1.5 * grp_budget_sum)), 1)
            
    dollars_earned_to_dollars_spent.plot(kind='bar', xticks=range(2010, 2019, 1), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Dollars', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the percentage of how many movies breakeven above each bar
    autolabel(axis, num_decimals=1)
    
plt.tight_layout()

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Dollars Earned For Every Dollar Spent This Decade (Includes Marketing)\n(Counts Labeled)', fontsize=20, y=1.05)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_gross_count = current_with_budget[current_with_budget[genre]].groupby('release_year')['domestic_adj'].count().copy()
    grp_gross_sum = current_with_budget[current_with_budget[genre]].groupby('release_year')['domestic_adj'].sum().copy()
    
    grp_budget_count = current_with_budget[current_with_budget[genre]].groupby('release_year')['budget_adj'].count().copy()
    grp_budget_sum = current_with_budget[current_with_budget[genre]].groupby('release_year')['budget_adj'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for year in range(2010, 2019, 1):
        if year not in grp_gross_count.index:
            grp_gross_count.loc[year] = 0
            grp_gross_sum.loc[year] = 0
        
        if year not in grp_budget_count.index:
            grp_budget_count.loc[year] = 0
            grp_budget_sum.loc[year] = 1

    # Sort the series by their index to have the decades in chronological order                
    grp_gross_count.sort_index(ascending=True, inplace=True)
    grp_gross_sum.sort_index(ascending=True, inplace=True)
    grp_budget_count.sort_index(ascending=True, inplace=True)
    grp_budget_sum.sort_index(ascending=True, inplace=True)
    
    dollars_earned_to_dollars_spent = round((grp_gross_sum / (1.5 * grp_budget_sum)), 1)
            
    dollars_earned_to_dollars_spent.plot(kind='bar', xticks=range(2010, 2019, 1), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Dollars', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the count of how many movies breakeven above each bar
    #utolabel(axis, to_round=False)
    autolabel(axis, counts=grp_gross_count.values)
    
plt.tight_layout()

# %% [markdown]
# ### Quick Takeaways
#
# For the past decade, `Horror` seems to trump the other genres in terms of the dollar earned per dollar risked metric. And yet, it has some of the lowest numbers of movies produced. Perhaps this is because `Horror` is more of a niche genre, frequently produced by independent studios.
#
# What is surprising is how low the dollar for dollar numbers are. Movies (at least domestically) aren't slam dunks by any means. If not for the worldwide market and ancillary revenue streams, movie studios should probably put their money elsewhere.

# %% [markdown]
# # Analyze By Release Week

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Mean Domestic Gross By Genre And Release Week', fontsize=20, y=1.02)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    grp = data[data[genre]].groupby('release_week').mean() / 1000000
    grp.plot(kind='bar', y='domestic_adj', xticks=range(1, 54), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Domestic Gross In Millions', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)

plt.tight_layout()

# %% [markdown]
# Key Takeaways:
#
# **Summer release**
#   - `Action` and `Adventure` benefit the most from being a Summer release, although all genres have a bump there.
#
# **Winter holidays release**
#   - `Action`, `Adventure`, and `Horror` seem to have the biggest bumps here.

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Mean Production Budget By Genre And Release Week', fontsize=20, y=1.02)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    grp = data[data[genre]].groupby('release_week').mean() / 1000000
    grp.plot(kind='bar', y='budget_adj', xticks=range(1, 54), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Budget In Millions', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)

plt.tight_layout()

# %% [markdown]
# Key Takeaways:
# - `Action` and `Adventure` have much larger budgets in general
# - `Thriller/Suspense` is third
# - `Drama`, `Comedy`, and `Horror` all have approximately the same mean budget

# %%
figure, axes = plt.subplots(nrows=6, ncols=1, sharex=True, sharey=True, figsize=(24, 16))
figure.suptitle('Percentage of Movies That Breakeven By Release Week', fontsize=20, y=1.02)

ax1, ax2, ax3, ax4, ax5, ax6 = axes.flatten()
axes_list = [ax1, ax2, ax3, ax4, ax5, ax6]

for genre, axis, color in zip(genres, axes_list, colors):
    # Create two series with decades as indexes and count and sum as values
    grp_count = data[data[genre]].groupby('release_week')['domestic_breakeven'].count().copy()
    grp_sum = data[data[genre]].groupby('release_week')['domestic_breakeven'].sum().copy()

    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for week in range(1, 54):
        if week not in grp_count.index:
            grp_count.loc[week] = 0
            grp_sum.loc[week] = 0

    # Sort the series by their index to have the decades in chronological order                
    grp_count.sort_index(ascending=True, inplace=True)
    grp_sum.sort_index(ascending=True, inplace=True)

    (grp_sum / grp_count * 100).plot(kind='bar', xticks=range(1, 54), ax=axis, linewidth=3, color=color)
    axis.set_ylabel('Percentage', fontsize=12)
    axis.legend([genre], loc=2, fontsize=15)
    
    # Put the count of how many movies breakeven above each bar
    autolabel(axis, counts=grp_count.values)
    
plt.tight_layout()

# %%
print('Number of release weeks a genre has never broken even:')

for genre in genres:
    grp_count = data[data[genre]].groupby('release_week')['domestic_breakeven'].count().copy()
    grp_sum = data[data[genre]].groupby('release_week')['domestic_breakeven'].sum().copy()
    
    # If the series is missing a decade, add it as an index
    # Then set the count to 1 and the sum to 0
    # This avoids division by zero problems when calculating the percentages
    for week in range(1, 54):
        if week not in grp_count.index:
            grp_count.loc[week] = 0
            grp_sum.loc[week] = 0
    
    breakeven_series = (grp_sum / grp_count * 100)
    empty_week_count = 0
    
    for week in breakeven_series:
        if week == 0:
            empty_week_count += 1
    
    print('{0:<20} {1}'.format(genre.title(), empty_week_count))

# %% [markdown]
# ## Quick Takeaways
# - `Action`, `Adventure` and `Thriller/Suspense` have the largest number of release weeks with no chance of breaking even domestically
# - `Comedy` and `Drama` are the least affected by release week. They can be profitable when released on almost any week
# - Each genre has had a chance at every release week (except the 53rd week which doesn't really count). Whether the success or failure can partially be attributed to the release week is another story.

# %% [markdown]
# # Conclusions
#
# **Safest**
#   - With a low mean production budget and high chance of profitability, `Horror` seems like the safest genre to invest in domestically.
#
# **Highest potential return per movie**
#   - If we are trying to maximize our revenue per movie produced, then either `Action` or `Adventure` are the best. They carry with them much higher production budgets, but also gross higher amounts than all other genres.
#
# **Most calendar-friendly**
#   - `Comedy` and `Drama` are the least affected by release week. If we want maximum flexibility there (for example, to avoid opening the same weekend as another big movie), we can plug and play one of these genres into almost any week.
#
# **Recent box office trends**
#   - In the past decade, the most consistent genre in terms of average performance per movie is `Horror`, followed by `Thriller/Suspense`. If we want to follow trends, these genres carry lower production budgets than the blockbuster genres, but our return ceiling is definitely capped.
#
# **Advice to our bosses**
#   - We need to investigate these genres according to their worldwide box office results. It's good to know how the domestic market is, but increasingly, a movie's profitability depends heavily on the foreign market.
#   - We will investigate this subject area next and see if the trends we've found here carry over.
#   - If pressed for a genre to release domestically tomorrow, and our primary concern was not losing the studio's money, I would recommend `Horror`.
